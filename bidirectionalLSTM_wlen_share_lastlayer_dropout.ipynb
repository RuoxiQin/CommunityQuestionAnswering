# %%
import numpy as np
import tensorflow as tf

# %%
sentence_length = 100
vector_size = 300
batch_size = 16
hidden_units1 = 64
hidden_units2 = 64
pre_dense_units1 = 128
learning_rate = 0.001
droprate_output = 0.8
droprate_state = 0.8
drop_rate = 0.5
augment_feature_num = 10
dense_units1 = 256
dense_units2 = 128
reg_coefficient = 0.001

# %% [markdown]
# ## Data Generator
#
# You can impelment whatever you want, just make sure to have the *has_next* and *get_batch* function with the corresponding output format.

# %%
class DataGenerator:
    def __init__(self, data_dir):
        '''Initialization'''
        npz_data = np.load(data_dir)
        names = sorted(npz_data.files)
        self._data = []
        for name in names:
            self._data.append(npz_data[name])
        self._num_examples = self._data[0].shape[0]

    def shuffle_data(self, idx):
        for i in range(len(self._data)):
            self._data[i]=self._data[i][idx]

    def get_data(self, start, end):
        res=[]
        for i in range(len(self._data)):
            res.append(self._data[i][start : end])
        return tuple(res)
    
    def init_epoch(self, batch_size, shuffle=True):
        self._index_in_epoch = 0
        idx = np.arange(0, self._num_examples)  # get all possible indexes
        if shuffle:
            np.random.shuffle(idx)  # shuffle indexes
        self.shuffle_data(idx)  # get list of `num` random samples
        if batch_size <= 0:
            self.batch_size = self._num_examples
        else:
            self.batch_size = batch_size

    def has_next(self):
        '''return bool: whether there is a next batch'''
        return self._index_in_epoch < self._num_examples

    def get_batch(self):
        '''
        return the next batch in the following tuple format:
        (batch_input_q, batch_input_a, augmented_data, score_label)
        Where
        batch_input_q: word2vec representation for the question in shape [batch_size, sentence_length, vector_size]
        batch_input_a: word2vec representation for the answer in shape [batch_size, sentence_length, vector_size]
        batch_q_len: [batch_size]
        batch_a_len: [batch_size]
        augmented_data: the extra data for MLP in shape [batch_size, augment_feature_num]
        score_label: ground truth semantic similarity score in shape [batch_size, 1]
        comment_id: the commet id
        '''
        start = self._index_in_epoch
        self._index_in_epoch += self.batch_size
        end = self._index_in_epoch
        return self.get_data(start, end)

# %% [markdown]
# ## Model Definition

# %%
tf.reset_default_graph()

# %%
# placeholders
batch_input_q = tf.placeholder(dtype=tf.float32, shape=(None, sentence_length, vector_size))
batch_input_a = tf.placeholder(dtype=tf.float32, shape=(None, sentence_length, vector_size))
batch_input_q_len = tf.placeholder(dtype=tf.int32, shape=(None,))
batch_input_a_len = tf.placeholder(dtype=tf.int32, shape=(None,))
score_label = tf.placeholder(dtype=tf.float32, shape=(None, 1))
enable_dropout = tf.placeholder(dtype=tf.bool, shape=())

# %%
# 2 bidirectional lstm layers
def blstm_func(input_batch, sequence_length):
    with tf.variable_scope("blstm1"):
        cell_fw1 = tf.nn.rnn_cell.LSTMCell(num_units=hidden_units1, name='forward')
        cell_fw1 = tf.nn.rnn_cell.DropoutWrapper(cell_fw1, output_keep_prob=droprate_output, state_keep_prob=droprate_state, variational_recurrent=True, dtype=tf.float32)
        cell_bw1 = tf.nn.rnn_cell.LSTMCell(num_units=hidden_units1, name='backward')
        cell_bw1 = tf.nn.rnn_cell.DropoutWrapper(cell_bw1, output_keep_prob=droprate_output, state_keep_prob=droprate_state, variational_recurrent=True, dtype=tf.float32)
        outputs1, _ = tf.nn.bidirectional_dynamic_rnn(
            cell_fw=cell_fw1, cell_bw=cell_bw1, inputs=input_batch, sequence_length=sequence_length, dtype=tf.float32)
        output_blstm1 = tf.concat(values=outputs1, axis=2)
    with tf.variable_scope("blstm2"):
        cell_fw2 = tf.nn.rnn_cell.LSTMCell(num_units=hidden_units2, name='forward')
        cell_fw2 = tf.nn.rnn_cell.DropoutWrapper(cell_fw2, output_keep_prob=droprate_output, state_keep_prob=droprate_state, variational_recurrent=True, dtype=tf.float32)
        cell_bw2 = tf.nn.rnn_cell.LSTMCell(num_units=hidden_units2, name='backward')
        cell_bw2 = tf.nn.rnn_cell.DropoutWrapper(cell_bw2, output_keep_prob=droprate_output, state_keep_prob=droprate_state, variational_recurrent=True, dtype=tf.float32)
        _, states2 = tf.nn.bidirectional_dynamic_rnn(
            cell_fw=cell_fw2, cell_bw=cell_bw2, inputs=output_blstm1, sequence_length=sequence_length, dtype=tf.float32)
        return tf.concat(values=[states2[0].h, states2[1].h], axis=1)

# %%
# pre dense layers
def pre_dense_func(input_batch):
    with tf.variable_scope("pre_dense"):
        #pre_dropout1 = tf.layers.dropout(input_batch, rate=drop_rate, training=enable_dropout, name='pre_dropout1')
        pre_dense1 = tf.layers.dense(input_batch, pre_dense_units1, activation=tf.nn.relu, name='pre_dense1')
        return pre_dense1

# %%
# bidirectional lstms
# Q lstms
with tf.variable_scope('blstm_model') as scope:
    q_output_lstm = blstm_func(batch_input_q, batch_input_q_len)
    q_outputs = pre_dense_func(q_output_lstm)
# A lstms
with tf.variable_scope(scope, reuse=True):
    a_output_lstm = blstm_func(batch_input_a, batch_input_a_len)
    a_outputs = pre_dense_func(a_output_lstm)
mlp_batch_input = tf.concat(values=[q_outputs, a_outputs], axis=1)
# Out:
# WARNING:tensorflow:From /share/pkg/tensorflow/r1.10/install/py3-gpu/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py:430: calling reverse_sequence (from tensorflow.python.ops.array_ops) with seq_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# seq_dim is deprecated, use seq_axis instead
# WARNING:tensorflow:From /share/pkg/tensorflow/r1.10/install/py3-gpu/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:454: calling reverse_sequence (from tensorflow.python.ops.array_ops) with batch_dim is deprecated and will be removed in a future version.
# Instructions for updating:
# batch_dim is deprecated, use batch_axis instead

# %%
# multi-layers perceptrons
with tf.variable_scope('final_dense'):
    dropout0 = tf.layers.dropout(mlp_batch_input, rate=drop_rate, training=enable_dropout, name='dropout0')
    dense1 = tf.layers.dense(dropout0, dense_units1, activation=tf.nn.relu, name='dense1')
    dropout1 = tf.layers.dropout(dense1, rate=drop_rate, training=enable_dropout, name='dropout1')
    dense2 = tf.layers.dense(dropout1, dense_units2, activation=tf.nn.relu, name='dense2')
    dropout2 = tf.layers.dropout(dense2, rate=drop_rate, training=enable_dropout, name='dropout2')
    logits = tf.layers.dense(dropout2, 1, name='final_output')
    batch_loss = tf.losses.mean_squared_error(score_label, logits)
    tf.summary.scalar('batch_mse_loss', batch_loss)

# %%
# regularization term
tv = tf.trainable_variables()
regularization = tf.reduce_sum([tf.nn.l2_loss(v) for v in tv])
tf.summary.scalar('regularization', regularization)
loss_with_reg = batch_loss
#tf.summary.scalar('loss_with_regularization', loss_with_reg)

# %%
# optimizer
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_with_reg, name='train_op')

# %% [markdown]
# ## Model training

# %%
root_dir = 'result_qa_wlen_sharepre_lastlayer_dropout' + str(hidden_units1) + '_' + str(hidden_units2) + '_' +\
str(pre_dense_units1) + '_' + \
str(dense_units1) + '_' + str(dense_units2)
log_dir = root_dir + '/log'
tensorboard_dir = root_dir + '/tensorboard'
cQA_train_embedding_dir = 'cQA_train_embedding_wlen.npz'
cQA_test_embedding_dir = 'cQA_test_embedding_wlen.npz'
epoch_num = 20
load_model = False
save_model = True
print_train_info = True
print_test_info = True
print_train_batch = 50
print_test_epoch = 1
save_model_epoch = 1
saver = tf.train.Saver()
summary_op = tf.summary.merge_all()

# %%
train_data_generator = DataGenerator(cQA_train_embedding_dir)
test_data_generator = DataGenerator(cQA_test_embedding_dir)

# %% [markdown]
# # Validation Function

# %%
def predict_score(matrices, log_dir):
    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, log_dir + "/model.ckpt")
        input_q, input_a, input_q_len, input_a_len = matrices
        scores = sess.run(logits, feed_dict={
                batch_input_q: input_q,
                batch_input_a: input_a,
                batch_input_q_len: input_q_len,
                batch_input_a_len: input_a_len,
                enable_dropout: False})
        return scores

# %%
def test_driver(data_generator, log_dir, thread_len=10):
    data_generator.init_epoch(-1, shuffle=False)
    input_q, input_a, input_q_len, input_a_len, aug_data, label_vec, cid_list = data_generator.get_batch()
    pred_vec = predict_score([input_q, input_a, input_q_len, input_a_len], log_dir)
    ans = []
    ans_human = []
    print(label_vec.shape, pred_vec.shape)
    for i in range(0, input_q.shape[0], thread_len):
        tmp_rank = []
        tmp_rank_human = []
        for j in range(thread_len):
            tmp_rank.append((float(pred_vec[i + j]), j, round(2 * float(label_vec[i + j]))))
            tmp_rank_human.append((float(pred_vec[i + j]), j, round(2 * float(label_vec[i + j])), str(cid_list[i + j][0])))
        tmp_rank.sort(reverse=True)
        tmp_rank_human.sort(reverse=True)
        ans.append(tmp_rank)
        ans_human.append(tmp_rank_human)
    return ans, ans_human

# %%
# MAP
class MeasurementCalculator:
    def __init__(self, resultFromModel, threshold=1):
        self.resultFromModel = resultFromModel
        self.binaryResult = self.toBinaryResult(threshold)
        
    def toBinaryResult(self, threshold):
        binaryResult = []
        for eachBatch in self.resultFromModel:
            eachBinaryResult = []
            for eachComment in eachBatch:
                
                # eachComment[0] -> score
                # eachComment[1] -> cid
                # eachComment[2] -> label
                currentLabel = eachComment[2]
                if currentLabel >= threshold:
                    eachBinaryResult.append(1)
                else:
                    eachBinaryResult.append(0)
                    
            if len(eachBinaryResult) != len(eachBatch):
                print('binary single batch length not equal to each bathch size...')
                return None
            binaryResult.append(eachBinaryResult)
        return binaryResult
        
    def precisionAtk(self, r, k):
        """Score is precision @ k
        Relevance is binary (nonzero is relevant).
        >>> r = [0, 0, 1]
        >>> precisionAtk(r, 1)
        0.0
        >>> precisionAtk(r, 2)
        0.0
        >>> precisionAtk(r, 3)
        0.33333333333333331
        >>> precisionAtk(r, 4)
        Traceback (most recent call last):
            File "<stdin>", line 1, in ?
        ValueError: Relevance score length < k
        Args:
            r: Relevance scores (list or numpy) in rank order
                (first element is the first item)
        Returns:
            Precision @ k
        Raises:
            ValueError: len(r) must be >= k
        """
        assert k >= 1
        r = np.asarray(r)[:k] != 0
    #     print('processing:')
    #     print(r)
    
        if r.size != k:
            raise ValueError('Relevance score length < k')
        return np.mean(r)

    def averagePrecision(self, r):
        """Score is average precision (area under PR curve)
        Relevance is binary (nonzero is relevant).
        >>> r = [1, 1, 0, 1, 0, 1, 0, 0, 0, 1]
        >>> delta_r = 1. / sum(r)
        >>> sum([sum(r[:x + 1]) / (x + 1.) * delta_r for x, y in enumerate(r) if y])
        0.7833333333333333
        >>> average_precision(r)
        0.78333333333333333
        Args:
            r: Relevance scores (list or numpy) in rank order
                (first element is the first item)
        Returns:
            Average precision
        """
        r = np.asarray(r) != 0
        out = [self.precisionAtk(r, k + 1) for k in range(r.size) if r[k]]
        if not out:
            return 0.
        return np.mean(out)

#     def meanAveragePrecision(self, rs):
    def meanAveragePrecision(self):
        """Score is mean average precision
        Relevance is binary (nonzero is relevant).
        >>> rs = [[1, 1, 0, 1, 0, 1, 0, 0, 0, 1]]
        >>> mean_average_precision(rs)
        0.78333333333333333
        >>> rs = [[1, 1, 0, 1, 0, 1, 0, 0, 0, 1], [0]]
        >>> mean_average_precision(rs)
        0.39166666666666666
        Args:
            rs: Iterator of relevance scores (list or numpy) in rank order
                (first element is the first item)
        Returns:
            Mean average precision
        """
        rs = self.binaryResult
        return np.mean([self.averagePrecision(r) for r in rs])
    
    # MRR
#     def meanReciprocalRank(rs):
    def meanReciprocalRank(self):
        # Eample
        """Score is reciprocal of the rank of the first relevant item
        First element is 'rank 1'.  Relevance is binary (nonzero is relevant).
        Example from http://en.wikipedia.org/wiki/Mean_reciprocal_rank
        >>> rs = [[0, 0, 1], [0, 1, 0], [1, 0, 0]]
        >>> mean_reciprocal_rank(rs)
        0.61111111111111105
        >>> rs = np.array([[0, 0, 0], [0, 1, 0], [1, 0, 0]])
        >>> mean_reciprocal_rank(rs)
        0.5
        >>> rs = [[0, 0, 0, 1], [1, 0, 0], [1, 0, 0]]
        >>> mean_reciprocal_rank(rs)
        0.75
        Args:
            rs: Iterator of relevance scores (list or numpy) in rank order
                (first element is the first item)
        Returns:
            Mean reciprocal rank
        """
        rs = self.binaryResult
        rs = (np.asarray(r).nonzero()[0] for r in rs)
        return np.mean([1. / (r[0] + 1) if r.size else 0. for r in rs])
    
    # AveRec
    def recallAtk(self, r, k):
        assert k >= 1
        totalOne = sum(r)
        retrivedOne = sum(r[:k])
        return retrivedOne / totalOne

    def averageRecallEach(self, r):
        #r = np.asarray(r) != 0
        #out = [self.recallAtk(r, k + 1) for k in range(r.size) if r[k]]
        out = [self.recallAtk(r, k + 1) for k in range(len(r)) if r[k]]
        if not out:
            return 0.
        return np.mean(out)

    def averageRecall(self):
        rs = self.binaryResult
        return np.mean([self.averageRecallEach(r) for r in rs])

# %% [markdown]
# # Run training

# %%
# training
with tf.Session() as sess:
    writer = tf.summary.FileWriter(tensorboard_dir, sess.graph)
    if load_model:
        saver.restore(sess, log_dir + "/model.ckpt")
    else:
        sess.run(tf.global_variables_initializer())
    batch_i = 0
    for epoch_i in range(epoch_num):
        train_data_generator.init_epoch(batch_size)
        while train_data_generator.has_next():
            input_q, input_a, input_q_len, input_a_len, aug_data, labels, _ = train_data_generator.get_batch()
            _, summary_log, current_batch_loss = sess.run([train_op, summary_op, batch_loss], feed_dict={
                batch_input_q: input_q,
                batch_input_a: input_a,
                batch_input_q_len: input_q_len,
                batch_input_a_len: input_a_len,
                score_label: labels,
                enable_dropout: True})
            batch_i += 1
            if print_train_info and batch_i % print_train_batch == 0:
                writer.add_summary(summary_log, batch_i)
                print('Epoch %d batch %d: training loss %f' % (epoch_i, batch_i, current_batch_loss.item()))
        print('Epoch %d done: training loss %f' % (epoch_i, current_batch_loss.item()))
        if print_test_info and epoch_i % print_test_epoch == 0:
            test_data_generator.init_epoch(-1, False)
            input_q, input_a, input_q_len, input_a_len, aug_data, labels, _ = test_data_generator.get_batch()
            test_batch_loss = sess.run([batch_loss], feed_dict={
                batch_input_q: input_q,
                batch_input_a: input_a,
                batch_input_q_len: input_q_len,
                batch_input_a_len: input_a_len,
                score_label: labels,
                enable_dropout: False})
            print('Epoch %d done: testing loss %f' % (epoch_i, test_batch_loss[0].item()))
        if save_model and epoch_i % save_model_epoch == 0:
            save_path = saver.save(sess, log_dir + "/model.ckpt")
            ranks, _ = test_driver(test_data_generator, log_dir)
            mc = MeasurementCalculator(ranks, 2)
            print('Epoch %d done: testing MAP %f, MPR %f' % (epoch_i, mc.meanAveragePrecision(), mc.meanReciprocalRank()))
    writer.close()
# Out:
# Epoch 0 batch 50: training loss 0.227241
# Epoch 0 batch 100: training loss 0.155490
# Epoch 0 batch 150: training loss 0.190699
# Epoch 0 batch 200: training loss 0.167257
# Epoch 0 batch 250: training loss 0.202640
# Epoch 0 batch 300: training loss 0.155053
# Epoch 0 batch 350: training loss 0.193942
# Epoch 0 batch 400: training loss 0.197168
# Epoch 0 batch 450: training loss 0.188380
# Epoch 0 batch 500: training loss 0.212961
# Epoch 0 batch 550: training loss 0.187259
# Epoch 0 batch 600: training loss 0.137920
# Epoch 0 batch 650: training loss 0.223663
# Epoch 0 batch 700: training loss 0.147886
# Epoch 0 batch 750: training loss 0.154240
# Epoch 0 batch 800: training loss 0.171040
# Epoch 0 batch 850: training loss 0.156709
# Epoch 0 done: training loss 0.210562
# Epoch 0 done: testing loss 0.177611
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 0 done: testing MAP 0.715277, MPR 0.790798
# Epoch 1 batch 900: training loss 0.111638
# Epoch 1 batch 950: training loss 0.132502
# Epoch 1 batch 1000: training loss 0.136461
# Epoch 1 batch 1050: training loss 0.176310
# Epoch 1 batch 1100: training loss 0.147066
# Epoch 1 batch 1150: training loss 0.120950
# Epoch 1 batch 1200: training loss 0.069375
# Epoch 1 batch 1250: training loss 0.272238
# Epoch 1 batch 1300: training loss 0.163912
# Epoch 1 batch 1350: training loss 0.356130
# Epoch 1 batch 1400: training loss 0.147729
# Epoch 1 batch 1450: training loss 0.190779
# Epoch 1 batch 1500: training loss 0.128609
# Epoch 1 batch 1550: training loss 0.188287
# Epoch 1 batch 1600: training loss 0.192097
# Epoch 1 batch 1650: training loss 0.147020
# Epoch 1 batch 1700: training loss 0.157617
# Epoch 1 batch 1750: training loss 0.139837
# Epoch 1 done: training loss 0.130119
# Epoch 1 done: testing loss 0.164091
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 1 done: testing MAP 0.729900, MPR 0.804284
# Epoch 2 batch 1800: training loss 0.137057
# Epoch 2 batch 1850: training loss 0.078324
# Epoch 2 batch 1900: training loss 0.207163
# Epoch 2 batch 1950: training loss 0.235978
# Epoch 2 batch 2000: training loss 0.176106
# Epoch 2 batch 2050: training loss 0.154114
# Epoch 2 batch 2100: training loss 0.173415
# Epoch 2 batch 2150: training loss 0.159239
# Epoch 2 batch 2200: training loss 0.104892
# Epoch 2 batch 2250: training loss 0.187680
# Epoch 2 batch 2300: training loss 0.183591
# Epoch 2 batch 2350: training loss 0.115279
# Epoch 2 batch 2400: training loss 0.188493
# Epoch 2 batch 2450: training loss 0.157968
# Epoch 2 batch 2500: training loss 0.175336
# Epoch 2 batch 2550: training loss 0.165152
# Epoch 2 batch 2600: training loss 0.095563
# Epoch 2 done: training loss 0.278221
# Epoch 2 done: testing loss 0.182834
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 2 done: testing MAP 0.728093, MPR 0.802360
# Epoch 3 batch 2650: training loss 0.141264
# Epoch 3 batch 2700: training loss 0.093303
# Epoch 3 batch 2750: training loss 0.192142
# Epoch 3 batch 2800: training loss 0.080828
# Epoch 3 batch 2850: training loss 0.216808
# Epoch 3 batch 2900: training loss 0.067294
# Epoch 3 batch 2950: training loss 0.103601
# Epoch 3 batch 3000: training loss 0.108456
# Epoch 3 batch 3050: training loss 0.170914
# Epoch 3 batch 3100: training loss 0.098116
# Epoch 3 batch 3150: training loss 0.124956
# Epoch 3 batch 3200: training loss 0.118268
# Epoch 3 batch 3250: training loss 0.133649
# Epoch 3 batch 3300: training loss 0.166278
# Epoch 3 batch 3350: training loss 0.196707
# Epoch 3 batch 3400: training loss 0.113384
# Epoch 3 batch 3450: training loss 0.123617
# Epoch 3 batch 3500: training loss 0.073980
# Epoch 3 done: training loss 0.078020
# Epoch 3 done: testing loss 0.168701
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 3 done: testing MAP 0.729813, MPR 0.802620
# Epoch 4 batch 3550: training loss 0.146039
# Epoch 4 batch 3600: training loss 0.097743
# Epoch 4 batch 3650: training loss 0.147833
# Epoch 4 batch 3700: training loss 0.092588
# Epoch 4 batch 3750: training loss 0.087103
# Epoch 4 batch 3800: training loss 0.114071
# Epoch 4 batch 3850: training loss 0.161867
# Epoch 4 batch 3900: training loss 0.102753
# Epoch 4 batch 3950: training loss 0.086427
# Epoch 4 batch 4000: training loss 0.113815
# Epoch 4 batch 4050: training loss 0.187887
# Epoch 4 batch 4100: training loss 0.105609
# Epoch 4 batch 4150: training loss 0.170134
# Epoch 4 batch 4200: training loss 0.047730
# Epoch 4 batch 4250: training loss 0.082865
# Epoch 4 batch 4300: training loss 0.093543
# Epoch 4 batch 4350: training loss 0.171424
# Epoch 4 batch 4400: training loss 0.158264
# Epoch 4 done: training loss 0.115244
# Epoch 4 done: testing loss 0.161317
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 4 done: testing MAP 0.724507, MPR 0.804136
# Epoch 5 batch 4450: training loss 0.121048
# Epoch 5 batch 4500: training loss 0.079000
# Epoch 5 batch 4550: training loss 0.106135
# Epoch 5 batch 4600: training loss 0.136544
# Epoch 5 batch 4650: training loss 0.211739
# Epoch 5 batch 4700: training loss 0.065793
# Epoch 5 batch 4750: training loss 0.096788
# Epoch 5 batch 4800: training loss 0.131630
# Epoch 5 batch 4850: training loss 0.059699
# Epoch 5 batch 4900: training loss 0.150717
# Epoch 5 batch 4950: training loss 0.225235
# Epoch 5 batch 5000: training loss 0.140641
# Epoch 5 batch 5050: training loss 0.115461
# Epoch 5 batch 5100: training loss 0.151329
# Epoch 5 batch 5150: training loss 0.107415
# Epoch 5 batch 5200: training loss 0.134363
# Epoch 5 batch 5250: training loss 0.068025
# Epoch 5 done: training loss 0.168239
# Epoch 5 done: testing loss 0.168546
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 5 done: testing MAP 0.720485, MPR 0.789843
# Epoch 6 batch 5300: training loss 0.066632
# Epoch 6 batch 5350: training loss 0.133219
# Epoch 6 batch 5400: training loss 0.206963
# Epoch 6 batch 5450: training loss 0.051466
# Epoch 6 batch 5500: training loss 0.086159
# Epoch 6 batch 5550: training loss 0.160855
# Epoch 6 batch 5600: training loss 0.113158
# Epoch 6 batch 5650: training loss 0.176745
# Epoch 6 batch 5700: training loss 0.120077
# Epoch 6 batch 5750: training loss 0.201803
# Epoch 6 batch 5800: training loss 0.183540
# Epoch 6 batch 5850: training loss 0.144526
# Epoch 6 batch 5900: training loss 0.113911
# Epoch 6 batch 5950: training loss 0.110508
# Epoch 6 batch 6000: training loss 0.178699
# Epoch 6 batch 6050: training loss 0.146519
# Epoch 6 batch 6100: training loss 0.175773
# Epoch 6 batch 6150: training loss 0.080424
# Epoch 6 done: training loss 0.153922
# Epoch 6 done: testing loss 0.160008
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 6 done: testing MAP 0.720364, MPR 0.792199
# Epoch 7 batch 6200: training loss 0.110734
# Epoch 7 batch 6250: training loss 0.108168
# Epoch 7 batch 6300: training loss 0.109718
# Epoch 7 batch 6350: training loss 0.106311
# Epoch 7 batch 6400: training loss 0.130646
# Epoch 7 batch 6450: training loss 0.053396
# Epoch 7 batch 6500: training loss 0.168906
# Epoch 7 batch 6550: training loss 0.060632
# Epoch 7 batch 6600: training loss 0.135234
# Epoch 7 batch 6650: training loss 0.059459
# Epoch 7 batch 6700: training loss 0.087889
# Epoch 7 batch 6750: training loss 0.105364
# Epoch 7 batch 6800: training loss 0.146519
# Epoch 7 batch 6850: training loss 0.089025
# Epoch 7 batch 6900: training loss 0.105244
# Epoch 7 batch 6950: training loss 0.128884
# Epoch 7 batch 7000: training loss 0.106072
# Epoch 7 batch 7050: training loss 0.137649
# Epoch 7 done: training loss 0.097562
# Epoch 7 done: testing loss 0.168338
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 7 done: testing MAP 0.718358, MPR 0.788115
# Epoch 8 batch 7100: training loss 0.115203
# Epoch 8 batch 7150: training loss 0.089581
# Epoch 8 batch 7200: training loss 0.066410
# Epoch 8 batch 7250: training loss 0.195907
# Epoch 8 batch 7300: training loss 0.056457
# Epoch 8 batch 7350: training loss 0.095227
# Epoch 8 batch 7400: training loss 0.094727
# Epoch 8 batch 7450: training loss 0.047563
# Epoch 8 batch 7500: training loss 0.103895
# Epoch 8 batch 7550: training loss 0.113957
# Epoch 8 batch 7600: training loss 0.126141
# Epoch 8 batch 7650: training loss 0.075072
# Epoch 8 batch 7700: training loss 0.093563
# Epoch 8 batch 7750: training loss 0.127687
# Epoch 8 batch 7800: training loss 0.105394
# Epoch 8 batch 7850: training loss 0.103876
# Epoch 8 batch 7900: training loss 0.207400
# Epoch 8 done: training loss 0.060556
# Epoch 8 done: testing loss 0.172790
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 8 done: testing MAP 0.711935, MPR 0.794540
# Epoch 9 batch 7950: training loss 0.095602
# Epoch 9 batch 8000: training loss 0.073439
# Epoch 9 batch 8050: training loss 0.074038
# Epoch 9 batch 8100: training loss 0.031799
# Epoch 9 batch 8150: training loss 0.117797
# Epoch 9 batch 8200: training loss 0.086894
# Epoch 9 batch 8250: training loss 0.124588
# Epoch 9 batch 8300: training loss 0.058626
# Epoch 9 batch 8350: training loss 0.059577
# Epoch 9 batch 8400: training loss 0.047131
# Epoch 9 batch 8450: training loss 0.226227
# Epoch 9 batch 8500: training loss 0.033714
# Epoch 9 batch 8550: training loss 0.072717
# Epoch 9 batch 8600: training loss 0.115408
# Epoch 9 batch 8650: training loss 0.119310
# Epoch 9 batch 8700: training loss 0.137560
# Epoch 9 batch 8750: training loss 0.109861
# Epoch 9 batch 8800: training loss 0.056914
# Epoch 9 done: training loss 0.033803
# Epoch 9 done: testing loss 0.166448
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 9 done: testing MAP 0.709801, MPR 0.774039
# Epoch 10 batch 8850: training loss 0.033824
# Epoch 10 batch 8900: training loss 0.086143
# Epoch 10 batch 8950: training loss 0.150243
# Epoch 10 batch 9000: training loss 0.099809
# Epoch 10 batch 9050: training loss 0.049517
# Epoch 10 batch 9100: training loss 0.074418
# Epoch 10 batch 9150: training loss 0.220092
# Epoch 10 batch 9200: training loss 0.140058
# Epoch 10 batch 9250: training loss 0.058275
# Epoch 10 batch 9300: training loss 0.067793
# Epoch 10 batch 9350: training loss 0.069499
# Epoch 10 batch 9400: training loss 0.055471
# Epoch 10 batch 9450: training loss 0.085739
# Epoch 10 batch 9500: training loss 0.067980
# Epoch 10 batch 9550: training loss 0.151458
# Epoch 10 batch 9600: training loss 0.109978
# Epoch 10 batch 9650: training loss 0.221051
# Epoch 10 batch 9700: training loss 0.103774
# Epoch 10 done: training loss 0.064704
# Epoch 10 done: testing loss 0.168781
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 10 done: testing MAP 0.721894, MPR 0.797918
# Epoch 11 batch 9750: training loss 0.128623
# Epoch 11 batch 9800: training loss 0.034615
# Epoch 11 batch 9850: training loss 0.077821
# Epoch 11 batch 9900: training loss 0.042834
# Epoch 11 batch 9950: training loss 0.115077
# Epoch 11 batch 10000: training loss 0.064160
# Epoch 11 batch 10050: training loss 0.055429
# Epoch 11 batch 10100: training loss 0.060518
# Epoch 11 batch 10150: training loss 0.057672
# Epoch 11 batch 10200: training loss 0.231357
# Epoch 11 batch 10250: training loss 0.053380
# Epoch 11 batch 10300: training loss 0.112741
# Epoch 11 batch 10350: training loss 0.144860
# Epoch 11 batch 10400: training loss 0.072139
# Epoch 11 batch 10450: training loss 0.101397
# Epoch 11 batch 10500: training loss 0.108159
# Epoch 11 batch 10550: training loss 0.032825
# Epoch 11 done: training loss 0.040339
# Epoch 11 done: testing loss 0.178503
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 11 done: testing MAP 0.719366, MPR 0.800342
# Epoch 12 batch 10600: training loss 0.027835
# Epoch 12 batch 10650: training loss 0.101111
# Epoch 12 batch 10700: training loss 0.063141
# Epoch 12 batch 10750: training loss 0.083140
# Epoch 12 batch 10800: training loss 0.094228
# Epoch 12 batch 10850: training loss 0.039676
# Epoch 12 batch 10900: training loss 0.111778
# Epoch 12 batch 10950: training loss 0.056005
# Epoch 12 batch 11000: training loss 0.070800
# Epoch 12 batch 11050: training loss 0.064279
# Epoch 12 batch 11100: training loss 0.094232
# Epoch 12 batch 11150: training loss 0.036491
# Epoch 12 batch 11200: training loss 0.135571
# Epoch 12 batch 11250: training loss 0.051679
# Epoch 12 batch 11300: training loss 0.134336
# Epoch 12 batch 11350: training loss 0.111694
# Epoch 12 batch 11400: training loss 0.103249
# Epoch 12 batch 11450: training loss 0.166774
# Epoch 12 done: training loss 0.178320
# Epoch 12 done: testing loss 0.172369
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 12 done: testing MAP 0.723169, MPR 0.796022
# Epoch 13 batch 11500: training loss 0.050509
# Epoch 13 batch 11550: training loss 0.117058
# Epoch 13 batch 11600: training loss 0.032490
# Epoch 13 batch 11650: training loss 0.074361
# Epoch 13 batch 11700: training loss 0.068747
# Epoch 13 batch 11750: training loss 0.068760
# Epoch 13 batch 11800: training loss 0.069685
# Epoch 13 batch 11850: training loss 0.102594
# Epoch 13 batch 11900: training loss 0.023745
# Epoch 13 batch 11950: training loss 0.086555
# Epoch 13 batch 12000: training loss 0.051051
# Epoch 13 batch 12050: training loss 0.101816
# Epoch 13 batch 12100: training loss 0.089385
# Epoch 13 batch 12150: training loss 0.022391
# Epoch 13 batch 12200: training loss 0.176313
# Epoch 13 batch 12250: training loss 0.097382
# Epoch 13 batch 12300: training loss 0.141213
# Epoch 13 done: training loss 0.104602
# Epoch 13 done: testing loss 0.173371
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 13 done: testing MAP 0.714280, MPR 0.781798
# Epoch 14 batch 12350: training loss 0.056326
# Epoch 14 batch 12400: training loss 0.040444
# Epoch 14 batch 12450: training loss 0.118840
# Epoch 14 batch 12500: training loss 0.032979
# Epoch 14 batch 12550: training loss 0.038944
# Epoch 14 batch 12600: training loss 0.021658
# Epoch 14 batch 12650: training loss 0.063125
# Epoch 14 batch 12700: training loss 0.071115
# Epoch 14 batch 12750: training loss 0.102883
# Epoch 14 batch 12800: training loss 0.066351
# Epoch 14 batch 12850: training loss 0.078956
# Epoch 14 batch 12900: training loss 0.043950
# Epoch 14 batch 12950: training loss 0.118308
# Epoch 14 batch 13000: training loss 0.061483
# Epoch 14 batch 13050: training loss 0.036365
# Epoch 14 batch 13100: training loss 0.050548
# Epoch 14 batch 13150: training loss 0.217962
# Epoch 14 batch 13200: training loss 0.144856
# Epoch 14 done: training loss 0.060149
# Epoch 14 done: testing loss 0.180987
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 14 done: testing MAP 0.695293, MPR 0.765667
# Epoch 15 batch 13250: training loss 0.124458
# Epoch 15 batch 13300: training loss 0.110071
# Epoch 15 batch 13350: training loss 0.059618
# Epoch 15 batch 13400: training loss 0.062141
# Epoch 15 batch 13450: training loss 0.075547
# Epoch 15 batch 13500: training loss 0.155418
# Epoch 15 batch 13550: training loss 0.150034
# Epoch 15 batch 13600: training loss 0.145916
# Epoch 15 batch 13650: training loss 0.045324
# Epoch 15 batch 13700: training loss 0.041567
# Epoch 15 batch 13750: training loss 0.020011
# Epoch 15 batch 13800: training loss 0.040938
# Epoch 15 batch 13850: training loss 0.061317
# Epoch 15 batch 13900: training loss 0.093311
# Epoch 15 batch 13950: training loss 0.049625
# Epoch 15 batch 14000: training loss 0.076658
# Epoch 15 batch 14050: training loss 0.096060
# Epoch 15 batch 14100: training loss 0.141880
# Epoch 15 done: training loss 0.080831
# Epoch 15 done: testing loss 0.188870
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 15 done: testing MAP 0.713389, MPR 0.784304
# Epoch 16 batch 14150: training loss 0.110914
# Epoch 16 batch 14200: training loss 0.019727
# Epoch 16 batch 14250: training loss 0.027186
# Epoch 16 batch 14300: training loss 0.055152
# Epoch 16 batch 14350: training loss 0.028330
# Epoch 16 batch 14400: training loss 0.100378
# Epoch 16 batch 14450: training loss 0.076802
# Epoch 16 batch 14500: training loss 0.064191
# Epoch 16 batch 14550: training loss 0.033162
# Epoch 16 batch 14600: training loss 0.043636
# Epoch 16 batch 14650: training loss 0.043972
# Epoch 16 batch 14700: training loss 0.110536
# Epoch 16 batch 14750: training loss 0.049299
# Epoch 16 batch 14800: training loss 0.059009
# Epoch 16 batch 14850: training loss 0.061291
# Epoch 16 batch 14900: training loss 0.092629
# Epoch 16 batch 14950: training loss 0.046816
# Epoch 16 done: training loss 0.094211
# Epoch 16 done: testing loss 0.189124
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 16 done: testing MAP 0.706602, MPR 0.782092
# Epoch 17 batch 15000: training loss 0.030510
# Epoch 17 batch 15050: training loss 0.114749
# Epoch 17 batch 15100: training loss 0.020930
# Epoch 17 batch 15150: training loss 0.035640
# Epoch 17 batch 15200: training loss 0.045096
# Epoch 17 batch 15250: training loss 0.084901
# Epoch 17 batch 15300: training loss 0.068657
# Epoch 17 batch 15350: training loss 0.073970
# Epoch 17 batch 15400: training loss 0.039571
# Epoch 17 batch 15450: training loss 0.020418
# Epoch 17 batch 15500: training loss 0.099323
# Epoch 17 batch 15550: training loss 0.090382
# Epoch 17 batch 15600: training loss 0.031493
# Epoch 17 batch 15650: training loss 0.041099
# Epoch 17 batch 15700: training loss 0.080637
# Epoch 17 batch 15750: training loss 0.033028
# Epoch 17 batch 15800: training loss 0.104715
# Epoch 17 batch 15850: training loss 0.020508
# Epoch 17 done: training loss 0.063538
# Epoch 17 done: testing loss 0.190622
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 17 done: testing MAP 0.721117, MPR 0.793398
# Epoch 18 batch 15900: training loss 0.111810
# Epoch 18 batch 15950: training loss 0.055430
# Epoch 18 batch 16000: training loss 0.010776
# Epoch 18 batch 16050: training loss 0.038781
# Epoch 18 batch 16100: training loss 0.046172
# Epoch 18 batch 16150: training loss 0.078663
# Epoch 18 batch 16200: training loss 0.048919
# Epoch 18 batch 16250: training loss 0.038985
# Epoch 18 batch 16300: training loss 0.093565
# Epoch 18 batch 16350: training loss 0.049028
# Epoch 18 batch 16400: training loss 0.068562
# Epoch 18 batch 16450: training loss 0.113641
# Epoch 18 batch 16500: training loss 0.091942
# Epoch 18 batch 16550: training loss 0.027458
# Epoch 18 batch 16600: training loss 0.067879
# Epoch 18 batch 16650: training loss 0.038291
# Epoch 18 batch 16700: training loss 0.079492
# Epoch 18 batch 16750: training loss 0.070836
# Epoch 18 done: training loss 0.029042
# Epoch 18 done: testing loss 0.186277
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 18 done: testing MAP 0.719141, MPR 0.800348
# Epoch 19 batch 16800: training loss 0.080867
# Epoch 19 batch 16850: training loss 0.065821
# Epoch 19 batch 16900: training loss 0.059724
# Epoch 19 batch 16950: training loss 0.067828
# Epoch 19 batch 17000: training loss 0.037833
# Epoch 19 batch 17050: training loss 0.038818
# Epoch 19 batch 17100: training loss 0.069774
# Epoch 19 batch 17150: training loss 0.031104
# Epoch 19 batch 17200: training loss 0.037423
# Epoch 19 batch 17250: training loss 0.031379
# Epoch 19 batch 17300: training loss 0.039446
# Epoch 19 batch 17350: training loss 0.069206
# Epoch 19 batch 17400: training loss 0.047726
# Epoch 19 batch 17450: training loss 0.135661
# Epoch 19 batch 17500: training loss 0.039370
# Epoch 19 batch 17550: training loss 0.110596
# Epoch 19 batch 17600: training loss 0.026551
# Epoch 19 done: training loss 0.044380
# Epoch 19 done: testing loss 0.191820
# INFO:tensorflow:Restoring parameters from result_qa_wlen_sharepre_lastlayer_dropout64_64_128_256_128/log/model.ckpt
# (3270, 1) (3270, 1)
# Epoch 19 done: testing MAP 0.709710, MPR 0.784063

# %% [markdown]
# # Validation

# %%
ranks, ranks_human = test_driver(test_data_generator, log_dir)
# Out:
# INFO:tensorflow:Restoring parameters from result_qa_wlen_share_lastlayer_dropout64_64_128256_128/log/model.ckpt
# (3270, 1) (3270, 1)

# %% [markdown]
# You may preview the ranking result below. The first column is the similarity score predicted by our model. The second column is the time posted order. The third column is the label relevance (before normalizing to 0~1). The foruth column is the comment id in the original validation file.

# %%
ranks_human
# Out:
# [[(0.7385021448135376, 0, 2, 'Q318_R6_C1'),
#   (0.703393816947937, 8, 2, 'Q318_R6_C9'),
#   (0.6207829713821411, 2, 2, 'Q318_R6_C3'),
#   (0.5664440989494324, 9, 2, 'Q318_R6_C10'),
#   (0.33530154824256897, 3, 2, 'Q318_R6_C4'),
#   (0.21336519718170166, 6, 0, 'Q318_R6_C7'),
#   (0.19518594443798065, 1, 2, 'Q318_R6_C2'),
#   (0.16015751659870148, 4, 2, 'Q318_R6_C5'),
#   (0.09976594150066376, 5, 0, 'Q318_R6_C6'),
#   (0.07747498154640198, 7, 1, 'Q318_R6_C8')],
#  [(0.860008716583252, 4, 0, 'Q318_R52_C5'),
#   (0.8454567193984985, 3, 1, 'Q318_R52_C4'),
#   (0.7445143461227417, 8, 2, 'Q318_R52_C9'),
#   (0.6638294458389282, 2, 0, 'Q318_R52_C3'),
#   (0.6466549634933472, 6, 2, 'Q318_R52_C7'),
#   (0.3003670275211334, 0, 2, 'Q318_R52_C1'),
#   (0.2536035478115082, 9, 0, 'Q318_R52_C10'),
#   (0.24957628548145294, 1, 1, 'Q318_R52_C2'),
#   (0.2189798504114151, 7, 1, 'Q318_R52_C8'),
#   (0.2059301733970642, 5, 0, 'Q318_R52_C6')],
#  [(0.8887484073638916, 2, 2, 'Q319_R1_C3'),
#   (0.8831068277359009, 0, 2, 'Q319_R1_C1'),
#   (0.8795608282089233, 1, 2, 'Q319_R1_C2'),
#   (0.8655790090560913, 4, 2, 'Q319_R1_C5'),
#   (0.8416115045547485, 9, 0, 'Q319_R1_C10'),
#   (0.8183610439300537, 8, 2, 'Q319_R1_C9'),
#   (0.7851381897926331, 7, 0, 'Q319_R1_C8'),
#   (0.6938697099685669, 5, 2, 'Q319_R1_C6'),
#   (0.5796605348587036, 6, 0, 'Q319_R1_C7'),
#   (0.08055955171585083, 3, 1, 'Q319_R1_C4')],
#  [(0.7444769144058228, 8, 2, 'Q319_R2_C9'),
#   (0.2186516970396042, 3, 2, 'Q319_R2_C4'),
#   (0.19833219051361084, 1, 0, 'Q319_R2_C2'),
#   (0.1811496764421463, 9, 0, 'Q319_R2_C10'),
#   (0.13582725822925568, 2, 0, 'Q319_R2_C3'),
#   (0.11635909974575043, 5, 0, 'Q319_R2_C6'),
#   (0.09842194616794586, 0, 1, 'Q319_R2_C1'),
#   (0.09621268510818481, 7, 0, 'Q319_R2_C8'),
#   (0.0887981504201889, 6, 0, 'Q319_R2_C7'),
#   (0.08255898952484131, 4, 0, 'Q319_R2_C5')],
#  [(0.8894215822219849, 5, 2, 'Q319_R6_C6'),
#   (0.8030368089675903, 0, 2, 'Q319_R6_C1'),
#   (0.7809526920318604, 1, 2, 'Q319_R6_C2'),
#   (0.7024064064025879, 8, 2, 'Q319_R6_C9'),
#   (0.6881483793258667, 2, 2, 'Q319_R6_C3'),
#   (0.3535054326057434, 9, 2, 'Q319_R6_C10'),
#   (0.2857434153556824, 4, 2, 'Q319_R6_C5'),
#   (0.18598121404647827, 3, 2, 'Q319_R6_C4'),
#   (0.16149349510669708, 7, 2, 'Q319_R6_C8'),
#   (0.12463802099227905, 6, 2, 'Q319_R6_C7')],
#  [(0.9169905185699463, 7, 2, 'Q319_R40_C8'),
#   (0.8612363338470459, 6, 0, 'Q319_R40_C7'),
#   (0.7432301640510559, 8, 0, 'Q319_R40_C9'),
#   (0.6665312051773071, 1, 0, 'Q319_R40_C2'),
#   (0.5983883142471313, 2, 2, 'Q319_R40_C3'),
#   (0.31964290142059326, 4, 0, 'Q319_R40_C5'),
#   (0.20595210790634155, 0, 2, 'Q319_R40_C1'),
#   (0.12984631955623627, 3, 0, 'Q319_R40_C4'),
#   (0.11715054512023926, 5, 0, 'Q319_R40_C6'),
#   (0.11080296337604523, 9, 0, 'Q319_R40_C10')],
#  [(0.9591610431671143, 2, 2, 'Q319_R44_C3'),
#   (0.7123568058013916, 9, 1, 'Q319_R44_C10'),
#   (0.22617876529693604, 3, 0, 'Q319_R44_C4'),
#   (0.222226083278656, 5, 0, 'Q319_R44_C6'),
#   (0.1970781832933426, 0, 0, 'Q319_R44_C1'),
#   (0.1700076460838318, 1, 0, 'Q319_R44_C2'),
#   (0.1606319546699524, 7, 2, 'Q319_R44_C8'),
#   (0.14180481433868408, 4, 0, 'Q319_R44_C5'),
#   (0.1264827698469162, 8, 0, 'Q319_R44_C9'),
#   (0.09823109209537506, 6, 0, 'Q319_R44_C7')],
#  [(0.9752702713012695, 8, 2, 'Q320_R1_C9'),
#   (0.9019128084182739, 6, 1, 'Q320_R1_C7'),
#   (0.8855668306350708, 0, 2, 'Q320_R1_C1'),
#   (0.8486700057983398, 5, 1, 'Q320_R1_C6'),
#   (0.8410875797271729, 9, 0, 'Q320_R1_C10'),
#   (0.826322078704834, 4, 0, 'Q320_R1_C5'),
#   (0.8124925494194031, 2, 2, 'Q320_R1_C3'),
#   (0.6934923529624939, 1, 2, 'Q320_R1_C2'),
#   (0.08148154616355896, 3, 0, 'Q320_R1_C4'),
#   (0.0786363035440445, 7, 0, 'Q320_R1_C8')],
#  [(0.9037332534790039, 6, 2, 'Q320_R2_C7'),
#   (0.8991721868515015, 4, 0, 'Q320_R2_C5'),
#   (0.8902779817581177, 9, 2, 'Q320_R2_C10'),
#   (0.8629550933837891, 8, 2, 'Q320_R2_C9'),
#   (0.7990813851356506, 5, 2, 'Q320_R2_C6'),
#   (0.5404494404792786, 7, 2, 'Q320_R2_C8'),
#   (0.22041387856006622, 0, 0, 'Q320_R2_C1'),
#   (0.14610768854618073, 1, 2, 'Q320_R2_C2'),
#   (0.1424715518951416, 3, 0, 'Q320_R2_C4'),
#   (0.10864023864269257, 2, 0, 'Q320_R2_C3')],
#  [(0.9709497690200806, 4, 2, 'Q320_R5_C5'),
#   (0.9306701421737671, 2, 2, 'Q320_R5_C3'),
#   (0.9144331216812134, 6, 2, 'Q320_R5_C7'),
#   (0.8900661468505859, 0, 1, 'Q320_R5_C1'),
#   (0.8662655353546143, 1, 2, 'Q320_R5_C2'),
#   (0.8572759628295898, 7, 2, 'Q320_R5_C8'),
#   (0.8220934867858887, 5, 2, 'Q320_R5_C6'),
#   (0.6232985258102417, 9, 0, 'Q320_R5_C10'),
#   (0.3892570734024048, 3, 0, 'Q320_R5_C4'),
#   (0.15768609941005707, 8, 1, 'Q320_R5_C9')],
#  [(0.7763687372207642, 0, 1, 'Q320_R8_C1'),
#   (0.5923067331314087, 6, 1, 'Q320_R8_C7'),
#   (0.5802528858184814, 8, 2, 'Q320_R8_C9'),
#   (0.5163417458534241, 4, 1, 'Q320_R8_C5'),
#   (0.2536788880825043, 7, 0, 'Q320_R8_C8'),
#   (0.22540029883384705, 2, 1, 'Q320_R8_C3'),
#   (0.1901073455810547, 9, 0, 'Q320_R8_C10'),
#   (0.1836148500442505, 3, 1, 'Q320_R8_C4'),
#   (0.17592479288578033, 1, 0, 'Q320_R8_C2'),
#   (0.1752309501171112, 5, 0, 'Q320_R8_C6')],
#  [(0.9293428659439087, 3, 2, 'Q320_R10_C4'),
#   (0.74989914894104, 2, 2, 'Q320_R10_C3'),
#   (0.7339731454849243, 7, 1, 'Q320_R10_C8'),
#   (0.7048503160476685, 1, 0, 'Q320_R10_C2'),
#   (0.49944010376930237, 5, 2, 'Q320_R10_C6'),
#   (0.1475462168455124, 8, 2, 'Q320_R10_C9'),
#   (0.11588172614574432, 6, 0, 'Q320_R10_C7'),
#   (0.08042439818382263, 4, 0, 'Q320_R10_C5'),
#   (0.07362139225006104, 9, 0, 'Q320_R10_C10'),
#   (0.07252152264118195, 0, 0, 'Q320_R10_C1')],
#  [(0.6843520402908325, 0, 2, 'Q320_R12_C1'),
#   (0.654262125492096, 9, 2, 'Q320_R12_C10'),
#   (0.571745753288269, 4, 0, 'Q320_R12_C5'),
#   (0.3975611925125122, 8, 2, 'Q320_R12_C9'),
#   (0.22410106658935547, 3, 2, 'Q320_R12_C4'),
#   (0.20952938497066498, 2, 1, 'Q320_R12_C3'),
#   (0.18918821215629578, 1, 2, 'Q320_R12_C2'),
#   (0.18537072837352753, 5, 1, 'Q320_R12_C6'),
#   (0.08313356339931488, 6, 0, 'Q320_R12_C7'),
#   (0.08058063685894012, 7, 2, 'Q320_R12_C8')],
#  [(0.9428207874298096, 9, 0, 'Q320_R20_C10'),
#   (0.9407910108566284, 6, 2, 'Q320_R20_C7'),
#   (0.9379763603210449, 7, 1, 'Q320_R20_C8'),
#   (0.9364103078842163, 4, 2, 'Q320_R20_C5'),
#   (0.9244753122329712, 5, 2, 'Q320_R20_C6'),
#   (0.9235786199569702, 0, 2, 'Q320_R20_C1'),
#   (0.8870669603347778, 2, 2, 'Q320_R20_C3'),
#   (0.8792455196380615, 3, 1, 'Q320_R20_C4'),
#   (0.8530447483062744, 1, 0, 'Q320_R20_C2'),
#   (0.10858650505542755, 8, 0, 'Q320_R20_C9')],
#  [(0.9240145683288574, 9, 2, 'Q321_R2_C10'),
#   (0.9214514493942261, 8, 2, 'Q321_R2_C9'),
#   (0.8930842876434326, 4, 2, 'Q321_R2_C5'),
#   (0.8561774492263794, 3, 2, 'Q321_R2_C4'),
#   (0.8244422674179077, 0, 0, 'Q321_R2_C1'),
#   (0.7006176710128784, 1, 2, 'Q321_R2_C2'),
#   (0.5655118227005005, 6, 1, 'Q321_R2_C7'),
#   (0.5632085800170898, 2, 0, 'Q321_R2_C3'),
#   (0.1442459374666214, 7, 0, 'Q321_R2_C8'),
#   (0.10553789138793945, 5, 0, 'Q321_R2_C6')],
#  [(0.9866207838058472, 8, 0, 'Q321_R17_C9'),
#   (0.8793240785598755, 6, 0, 'Q321_R17_C7'),
#   (0.8400872945785522, 9, 0, 'Q321_R17_C10'),
#   (0.8099786043167114, 3, 2, 'Q321_R17_C4'),
#   (0.7174196243286133, 0, 0, 'Q321_R17_C1'),
#   (0.4304012954235077, 4, 2, 'Q321_R17_C5'),
#   (0.3247791826725006, 1, 2, 'Q321_R17_C2'),
#   (0.27154070138931274, 2, 0, 'Q321_R17_C3'),
#   (0.10317595303058624, 7, 0, 'Q321_R17_C8'),
#   (0.043306708335876465, 5, 0, 'Q321_R17_C6')],
#  [(0.9696832895278931, 9, 1, 'Q321_R28_C10'),
#   (0.93868088722229, 6, 2, 'Q321_R28_C7'),
#   (0.8891226053237915, 8, 1, 'Q321_R28_C9'),
#   (0.8836067914962769, 7, 0, 'Q321_R28_C8'),
#   (0.845117449760437, 4, 2, 'Q321_R28_C5'),
#   (0.747550368309021, 2, 0, 'Q321_R28_C3'),
#   (0.4090093672275543, 5, 1, 'Q321_R28_C6'),
#   (0.2500903904438019, 1, 0, 'Q321_R28_C2'),
#   (0.12961842119693756, 3, 0, 'Q321_R28_C4'),
#   (0.10574787855148315, 0, 0, 'Q321_R28_C1')],
#  [(0.7678567171096802, 2, 2, 'Q322_R1_C3'),
#   (0.7194548845291138, 7, 2, 'Q322_R1_C8'),
#   (0.6958516836166382, 8, 2, 'Q322_R1_C9'),
#   (0.6791684627532959, 9, 2, 'Q322_R1_C10'),
#   (0.659562349319458, 3, 2, 'Q322_R1_C4'),
#   (0.6546895503997803, 4, 2, 'Q322_R1_C5'),
#   (0.636178731918335, 0, 2, 'Q322_R1_C1'),
#   (0.609297513961792, 5, 2, 'Q322_R1_C6'),
#   (0.6065393686294556, 6, 2, 'Q322_R1_C7'),
#   (0.5868643522262573, 1, 2, 'Q322_R1_C2')],
#  [(0.921362042427063, 7, 2, 'Q322_R9_C8'),
#   (0.9051297903060913, 1, 2, 'Q322_R9_C2'),
#   (0.8964923620223999, 2, 2, 'Q322_R9_C3'),
#   (0.8920871019363403, 9, 0, 'Q322_R9_C10'),
#   (0.8223775625228882, 6, 1, 'Q322_R9_C7'),
#   (0.4306493401527405, 4, 1, 'Q322_R9_C5'),
#   (0.26663511991500854, 8, 1, 'Q322_R9_C9'),
#   (0.20988421142101288, 3, 2, 'Q322_R9_C4'),
#   (0.1477939486503601, 0, 1, 'Q322_R9_C1'),
#   (0.11586174368858337, 5, 1, 'Q322_R9_C6')],
#  [(0.920814037322998, 2, 2, 'Q322_R32_C3'),
#   (0.9013361930847168, 7, 2, 'Q322_R32_C8'),
#   (0.8996963500976562, 5, 2, 'Q322_R32_C6'),
#   (0.896809458732605, 6, 2, 'Q322_R32_C7'),
#   (0.8820977210998535, 9, 1, 'Q322_R32_C10'),
#   (0.41890788078308105, 1, 0, 'Q322_R32_C2'),
#   (0.32507795095443726, 3, 1, 'Q322_R32_C4'),
#   (0.31400352716445923, 8, 2, 'Q322_R32_C9'),
#   (0.2875503599643707, 4, 2, 'Q322_R32_C5'),
#   (0.07073536515235901, 0, 0, 'Q322_R32_C1')],
#  [(0.9707978963851929, 9, 2, 'Q322_R45_C10'),
#   (0.9707474708557129, 8, 2, 'Q322_R45_C9'),
#   (0.924911379814148, 1, 2, 'Q322_R45_C2'),
#   (0.8388136625289917, 4, 2, 'Q322_R45_C5'),
#   (0.48053401708602905, 6, 2, 'Q322_R45_C7'),
#   (0.4270901381969452, 3, 2, 'Q322_R45_C4'),
#   (0.4017166495323181, 7, 1, 'Q322_R45_C8'),
#   (0.2478020042181015, 5, 2, 'Q322_R45_C6'),
#   (0.18857409060001373, 0, 2, 'Q322_R45_C1'),
#   (0.1550692468881607, 2, 0, 'Q322_R45_C3')],
#  [(0.8916366100311279, 9, 1, 'Q322_R54_C10'),
#   (0.8730281591415405, 6, 1, 'Q322_R54_C7'),
#   (0.8215558528900146, 1, 1, 'Q322_R54_C2'),
#   (0.7879325747489929, 5, 1, 'Q322_R54_C6'),
#   (0.7151831984519958, 4, 0, 'Q322_R54_C5'),
#   (0.6695600748062134, 0, 1, 'Q322_R54_C1'),
#   (0.5781067609786987, 8, 1, 'Q322_R54_C9'),
#   (0.18301305174827576, 2, 0, 'Q322_R54_C3'),
#   (0.15899619460105896, 7, 0, 'Q322_R54_C8'),
#   (0.09731577336788177, 3, 0, 'Q322_R54_C4')],
#  [(0.9939149618148804, 7, 0, 'Q323_R2_C8'),
#   (0.9358816146850586, 3, 2, 'Q323_R2_C4'),
#   (0.920007586479187, 2, 2, 'Q323_R2_C3'),
#   (0.9130417108535767, 8, 2, 'Q323_R2_C9'),
#   (0.8740921020507812, 5, 2, 'Q323_R2_C6'),
#   (0.4892265796661377, 9, 2, 'Q323_R2_C10'),
#   (0.4596989154815674, 4, 2, 'Q323_R2_C5'),
#   (0.438814640045166, 1, 2, 'Q323_R2_C2'),
#   (0.2097451388835907, 0, 2, 'Q323_R2_C1'),
#   (0.17421624064445496, 6, 2, 'Q323_R2_C7')],
#  [(1.029362678527832, 9, 2, 'Q323_R4_C10'),
#   (0.9797043800354004, 2, 2, 'Q323_R4_C3'),
#   (0.8124632835388184, 1, 2, 'Q323_R4_C2'),
#   (0.7912726402282715, 8, 2, 'Q323_R4_C9'),
#   (0.7448387145996094, 7, 2, 'Q323_R4_C8'),
#   (0.6460930109024048, 3, 0, 'Q323_R4_C4'),
#   (0.6373209357261658, 4, 2, 'Q323_R4_C5'),
#   (0.6304202079772949, 5, 2, 'Q323_R4_C6'),
#   (0.2109723687171936, 6, 0, 'Q323_R4_C7'),
#   (0.11488881707191467, 0, 0, 'Q323_R4_C1')],
#  [(0.937410831451416, 4, 2, 'Q323_R6_C5'),
#   (0.8955179452896118, 9, 1, 'Q323_R6_C10'),
#   (0.8853007555007935, 5, 1, 'Q323_R6_C6'),
#   (0.8384081125259399, 8, 2, 'Q323_R6_C9'),
#   (0.8132428526878357, 2, 1, 'Q323_R6_C3'),
#   (0.4688246548175812, 1, 0, 'Q323_R6_C2'),
#   (0.37884971499443054, 3, 0, 'Q323_R6_C4'),
#   (0.2841232717037201, 7, 0, 'Q323_R6_C8'),
#   (0.17881274223327637, 6, 0, 'Q323_R6_C7'),
#   (0.11124478280544281, 0, 0, 'Q323_R6_C1')],
#  [(0.9367935657501221, 4, 0, 'Q323_R7_C5'),
#   (0.9207350015640259, 0, 2, 'Q323_R7_C1'),
#   (0.8906034231185913, 6, 0, 'Q323_R7_C7'),
#   (0.8560434579849243, 1, 2, 'Q323_R7_C2'),
#   (0.6891497373580933, 9, 2, 'Q323_R7_C10'),
#   (0.5608888268470764, 7, 2, 'Q323_R7_C8'),
#   (0.3989548683166504, 2, 2, 'Q323_R7_C3'),
#   (0.25740936398506165, 5, 0, 'Q323_R7_C6'),
#   (0.1992746889591217, 3, 0, 'Q323_R7_C4'),
#   (0.1624889373779297, 8, 2, 'Q323_R7_C9')],
#  [(0.8282788991928101, 1, 2, 'Q323_R10_C2'),
#   (0.8256723880767822, 7, 2, 'Q323_R10_C8'),
#   (0.8183852434158325, 0, 2, 'Q323_R10_C1'),
#   (0.7748070359230042, 9, 2, 'Q323_R10_C10'),
#   (0.660578727722168, 8, 2, 'Q323_R10_C9'),
#   (0.5507779717445374, 2, 2, 'Q323_R10_C3'),
#   (0.17718945443630219, 5, 2, 'Q323_R10_C6'),
#   (0.17129908502101898, 3, 0, 'Q323_R10_C4'),
#   (0.1388164907693863, 6, 2, 'Q323_R10_C7'),
#   (0.1336079239845276, 4, 2, 'Q323_R10_C5')],
#  [(0.9180639982223511, 4, 2, 'Q323_R12_C5'),
#   (0.8357428312301636, 8, 2, 'Q323_R12_C9'),
#   (0.6647915840148926, 1, 2, 'Q323_R12_C2'),
#   (0.4862130880355835, 0, 2, 'Q323_R12_C1'),
#   (0.24272677302360535, 9, 0, 'Q323_R12_C10'),
#   (0.20932717621326447, 5, 2, 'Q323_R12_C6'),
#   (0.1756361871957779, 7, 0, 'Q323_R12_C8'),
#   (0.12369266152381897, 3, 1, 'Q323_R12_C4'),
#   (0.0898694097995758, 6, 2, 'Q323_R12_C7'),
#   (0.010309070348739624, 2, 1, 'Q323_R12_C3')],
#  [(0.834023118019104, 0, 2, 'Q323_R13_C1'),
#   (0.788644552230835, 6, 0, 'Q323_R13_C7'),
#   (0.726598858833313, 1, 2, 'Q323_R13_C2'),
#   (0.7203671932220459, 9, 0, 'Q323_R13_C10'),
#   (0.5253828763961792, 5, 2, 'Q323_R13_C6'),
#   (0.49509888887405396, 2, 2, 'Q323_R13_C3'),
#   (0.4798499345779419, 7, 0, 'Q323_R13_C8'),
#   (0.2042933702468872, 3, 0, 'Q323_R13_C4'),
#   (0.15869860351085663, 8, 2, 'Q323_R13_C9'),
#   (0.14984416961669922, 4, 0, 'Q323_R13_C5')],
#  [(0.8678368330001831, 4, 2, 'Q323_R14_C5'),
#   (0.830459475517273, 6, 0, 'Q323_R14_C7'),
#   (0.8249908685684204, 9, 0, 'Q323_R14_C10'),
#   (0.6842782497406006, 2, 2, 'Q323_R14_C3'),
#   (0.6462426781654358, 3, 2, 'Q323_R14_C4'),
#   (0.2346542477607727, 8, 0, 'Q323_R14_C9'),
#   (0.1682676374912262, 0, 2, 'Q323_R14_C1'),
#   (0.15529456734657288, 7, 0, 'Q323_R14_C8'),
#   (0.13926908373832703, 1, 2, 'Q323_R14_C2'),
#   (0.1312371790409088, 5, 0, 'Q323_R14_C6')],
#  [(0.9433172941207886, 1, 0, 'Q323_R19_C2'),
#   (0.8551217317581177, 3, 2, 'Q323_R19_C4'),
#   (0.4844037890434265, 2, 0, 'Q323_R19_C3'),
#   (0.4249708652496338, 4, 0, 'Q323_R19_C5'),
#   (0.2541937232017517, 9, 0, 'Q323_R19_C10'),
#   (0.17278550565242767, 8, 0, 'Q323_R19_C9'),
#   (0.11831557750701904, 0, 0, 'Q323_R19_C1'),
#   (0.1019262969493866, 5, 0, 'Q323_R19_C6'),
#   (0.08046500384807587, 6, 0, 'Q323_R19_C7'),
#   (0.06073048710823059, 7, 0, 'Q323_R19_C8')],
#  [(1.0091828107833862, 5, 2, 'Q323_R20_C6'),
#   (0.9061483144760132, 8, 2, 'Q323_R20_C9'),
#   (0.8816947937011719, 0, 2, 'Q323_R20_C1'),
#   (0.8553295135498047, 7, 2, 'Q323_R20_C8'),
#   (0.8547412157058716, 2, 2, 'Q323_R20_C3'),
#   (0.8232772350311279, 3, 2, 'Q323_R20_C4'),
#   (0.7622014284133911, 4, 2, 'Q323_R20_C5'),
#   (0.6893596053123474, 9, 2, 'Q323_R20_C10'),
#   (0.5891183614730835, 6, 2, 'Q323_R20_C7'),
#   (0.24190989136695862, 1, 2, 'Q323_R20_C2')],
#  [(1.0051509141921997, 0, 2, 'Q324_R5_C1'),
#   (0.895164966583252, 8, 1, 'Q324_R5_C9'),
#   (0.637789249420166, 6, 1, 'Q324_R5_C7'),
#   (0.5734448432922363, 1, 2, 'Q324_R5_C2'),
#   (0.21394038200378418, 4, 0, 'Q324_R5_C5'),
#   (0.17972971498966217, 5, 0, 'Q324_R5_C6'),
#   (0.16911613941192627, 3, 0, 'Q324_R5_C4'),
#   (0.13689564168453217, 9, 0, 'Q324_R5_C10'),
#   (0.12316937744617462, 2, 1, 'Q324_R5_C3'),
#   (0.10435065627098083, 7, 0, 'Q324_R5_C8')],
#  [(0.9352049827575684, 7, 2, 'Q324_R21_C8'),
#   (0.8788636922836304, 1, 2, 'Q324_R21_C2'),
#   (0.8239468336105347, 6, 0, 'Q324_R21_C7'),
#   (0.770341157913208, 4, 2, 'Q324_R21_C5'),
#   (0.7509151697158813, 3, 2, 'Q324_R21_C4'),
#   (0.23222297430038452, 9, 1, 'Q324_R21_C10'),
#   (0.2077723890542984, 8, 0, 'Q324_R21_C9'),
#   (0.16783055663108826, 2, 2, 'Q324_R21_C3'),
#   (0.1378859430551529, 5, 0, 'Q324_R21_C6'),
#   (0.09143613278865814, 0, 0, 'Q324_R21_C1')],
#  [(0.9582980871200562, 7, 0, 'Q324_R36_C8'),
#   (0.8432614803314209, 9, 0, 'Q324_R36_C10'),
#   (0.7786006927490234, 8, 2, 'Q324_R36_C9'),
#   (0.5392367839813232, 6, 1, 'Q324_R36_C7'),
#   (0.43909329175949097, 1, 0, 'Q324_R36_C2'),
#   (0.24831843376159668, 4, 1, 'Q324_R36_C5'),
#   (0.21233080327510834, 3, 0, 'Q324_R36_C4'),
#   (0.14201781153678894, 2, 0, 'Q324_R36_C3'),
#   (0.10551919043064117, 0, 0, 'Q324_R36_C1'),
#   (0.05785036087036133, 5, 0, 'Q324_R36_C6')],
#  [(0.7918897867202759, 1, 2, 'Q325_R1_C2'),
#   (0.7040812373161316, 4, 1, 'Q325_R1_C5'),
#   (0.6656900644302368, 0, 1, 'Q325_R1_C1'),
#   (0.582671582698822, 6, 1, 'Q325_R1_C7'),
#   (0.4455631673336029, 5, 0, 'Q325_R1_C6'),
#   (0.3426033854484558, 7, 2, 'Q325_R1_C8'),
#   (0.24651479721069336, 2, 0, 'Q325_R1_C3'),
#   (0.2404816448688507, 8, 0, 'Q325_R1_C9'),
#   (0.20069946348667145, 3, 0, 'Q325_R1_C4'),
#   (0.10674971342086792, 9, 1, 'Q325_R1_C10')],
#  [(0.9207929372787476, 2, 2, 'Q325_R56_C3'),
#   (0.884979248046875, 6, 2, 'Q325_R56_C7'),
#   (0.8403218984603882, 4, 1, 'Q325_R56_C5'),
#   (0.7538474202156067, 7, 2, 'Q325_R56_C8'),
#   (0.6554398536682129, 1, 0, 'Q325_R56_C2'),
#   (0.6355602145195007, 5, 2, 'Q325_R56_C6'),
#   (0.23320874571800232, 8, 0, 'Q325_R56_C9'),
#   (0.20662270486354828, 0, 0, 'Q325_R56_C1'),
#   (0.19186630845069885, 3, 0, 'Q325_R56_C4'),
#   (0.094527468085289, 9, 0, 'Q325_R56_C10')],
#  [(0.9420100450515747, 3, 2, 'Q326_R3_C4'),
#   (0.9408811330795288, 5, 2, 'Q326_R3_C6'),
#   (0.9127264022827148, 8, 0, 'Q326_R3_C9'),
#   (0.8447370529174805, 7, 0, 'Q326_R3_C8'),
#   (0.8051116466522217, 6, 2, 'Q326_R3_C7'),
#   (0.8028866052627563, 0, 2, 'Q326_R3_C1'),
#   (0.21507251262664795, 2, 0, 'Q326_R3_C3'),
#   (0.15821436047554016, 9, 0, 'Q326_R3_C10'),
#   (0.13732409477233887, 1, 0, 'Q326_R3_C2'),
#   (0.11527468264102936, 4, 0, 'Q326_R3_C5')],
#  [(0.9751929044723511, 8, 2, 'Q326_R20_C9'),
#   (0.8532181978225708, 7, 0, 'Q326_R20_C8'),
#   (0.7459869384765625, 0, 2, 'Q326_R20_C1'),
#   (0.507337749004364, 3, 0, 'Q326_R20_C4'),
#   (0.5004435777664185, 4, 2, 'Q326_R20_C5'),
#   (0.21314045786857605, 1, 1, 'Q326_R20_C2'),
#   (0.1819300502538681, 6, 0, 'Q326_R20_C7'),
#   (0.1478240042924881, 5, 2, 'Q326_R20_C6'),
#   (0.12119302153587341, 2, 0, 'Q326_R20_C3'),
#   (-0.022144556045532227, 9, 0, 'Q326_R20_C10')],
#  [(0.9347661733627319, 3, 2, 'Q326_R25_C4'),
#   (0.9330365657806396, 2, 2, 'Q326_R25_C3'),
#   (0.8991265296936035, 4, 2, 'Q326_R25_C5'),
#   (0.8386404514312744, 9, 1, 'Q326_R25_C10'),
#   (0.8345201015472412, 0, 1, 'Q326_R25_C1'),
#   (0.8260012865066528, 6, 2, 'Q326_R25_C7'),
#   (0.7730237245559692, 1, 2, 'Q326_R25_C2'),
#   (0.6965230703353882, 8, 0, 'Q326_R25_C9'),
#   (0.32839804887771606, 5, 0, 'Q326_R25_C6'),
#   (0.11414851248264313, 7, 0, 'Q326_R25_C8')],
#  [(0.9320938587188721, 1, 0, 'Q326_R34_C2'),
#   (0.9109548330307007, 3, 1, 'Q326_R34_C4'),
#   (0.7881745100021362, 2, 2, 'Q326_R34_C3'),
#   (0.778003990650177, 6, 1, 'Q326_R34_C7'),
#   (0.6872162818908691, 0, 1, 'Q326_R34_C1'),
#   (0.3052977919578552, 7, 1, 'Q326_R34_C8'),
#   (0.1993209421634674, 9, 1, 'Q326_R34_C10'),
#   (0.15524199604988098, 5, 0, 'Q326_R34_C6'),
#   (0.0698586106300354, 4, 0, 'Q326_R34_C5'),
#   (0.06023848056793213, 8, 0, 'Q326_R34_C9')],
#  [(0.9019547700881958, 9, 0, 'Q326_R64_C10'),
#   (0.8877311944961548, 1, 2, 'Q326_R64_C2'),
#   (0.8547664880752563, 7, 0, 'Q326_R64_C8'),
#   (0.8425958156585693, 8, 0, 'Q326_R64_C9'),
#   (0.827923059463501, 6, 0, 'Q326_R64_C7'),
#   (0.7512067556381226, 5, 2, 'Q326_R64_C6'),
#   (0.6594440937042236, 0, 2, 'Q326_R64_C1'),
#   (0.2169601023197174, 2, 0, 'Q326_R64_C3'),
#   (0.18999849259853363, 4, 1, 'Q326_R64_C5'),
#   (0.15524818003177643, 3, 0, 'Q326_R64_C4')],
#  [(0.8943028450012207, 9, 2, 'Q326_R90_C10'),
#   (0.8764562606811523, 1, 2, 'Q326_R90_C2'),
#   (0.8711953163146973, 2, 2, 'Q326_R90_C3'),
#   (0.8468806743621826, 0, 2, 'Q326_R90_C1'),
#   (0.8093770146369934, 8, 2, 'Q326_R90_C9'),
#   (0.7148852348327637, 4, 1, 'Q326_R90_C5'),
#   (0.6787835955619812, 5, 2, 'Q326_R90_C6'),
#   (0.639824628829956, 3, 2, 'Q326_R90_C4'),
#   (0.5827988386154175, 6, 1, 'Q326_R90_C7'),
#   (0.1854473501443863, 7, 2, 'Q326_R90_C8')],
#  [(0.9434305429458618, 8, 1, 'Q327_R5_C9'),
#   (0.9396489858627319, 5, 1, 'Q327_R5_C6'),
#   (0.9039363861083984, 3, 1, 'Q327_R5_C4'),
#   (0.8756148815155029, 7, 1, 'Q327_R5_C8'),
#   (0.7907570600509644, 4, 1, 'Q327_R5_C5'),
#   (0.5571771860122681, 9, 1, 'Q327_R5_C10'),
#   (0.4899007976055145, 6, 0, 'Q327_R5_C7'),
#   (0.20377013087272644, 2, 1, 'Q327_R5_C3'),
#   (0.17166751623153687, 1, 0, 'Q327_R5_C2'),
#   (0.08265118300914764, 0, 0, 'Q327_R5_C1')],
#  [(0.8573393821716309, 3, 0, 'Q327_R29_C4'),
#   (0.8349107503890991, 5, 2, 'Q327_R29_C6'),
#   (0.7782870531082153, 6, 1, 'Q327_R29_C7'),
#   (0.7722179889678955, 9, 2, 'Q327_R29_C10'),
#   (0.2132081389427185, 0, 0, 'Q327_R29_C1'),
#   (0.19206970930099487, 4, 0, 'Q327_R29_C5'),
#   (0.19007210433483124, 8, 0, 'Q327_R29_C9'),
#   (0.18569034337997437, 7, 0, 'Q327_R29_C8'),
#   (0.13351812958717346, 2, 0, 'Q327_R29_C3'),
#   (0.0972997397184372, 1, 0, 'Q327_R29_C2')],
#  [(0.8943575620651245, 3, 2, 'Q327_R54_C4'),
#   (0.8664464950561523, 7, 2, 'Q327_R54_C8'),
#   (0.7630116939544678, 9, 0, 'Q327_R54_C10'),
#   (0.31534987688064575, 8, 1, 'Q327_R54_C9'),
#   (0.22870799899101257, 2, 2, 'Q327_R54_C3'),
#   (0.16573847830295563, 4, 0, 'Q327_R54_C5'),
#   (0.06048104166984558, 6, 1, 'Q327_R54_C7'),
#   (0.05522671341896057, 0, 0, 'Q327_R54_C1'),
#   (0.02682855725288391, 5, 0, 'Q327_R54_C6'),
#   (0.008962869644165039, 1, 1, 'Q327_R54_C2')],
#  [(0.6822810173034668, 2, 2, 'Q327_R78_C3'),
#   (0.3651964068412781, 8, 2, 'Q327_R78_C9'),
#   (0.24893921613693237, 9, 2, 'Q327_R78_C10'),
#   (0.2382432222366333, 1, 0, 'Q327_R78_C2'),
#   (0.23717540502548218, 6, 1, 'Q327_R78_C7'),
#   (0.21891728043556213, 3, 2, 'Q327_R78_C4'),
#   (0.20347960293293, 7, 0, 'Q327_R78_C8'),
#   (0.1362258940935135, 5, 0, 'Q327_R78_C6'),
#   (0.08235341310501099, 4, 0, 'Q327_R78_C5'),
#   (0.003872692584991455, 0, 0, 'Q327_R78_C1')],
#  [(0.8837714195251465, 5, 2, 'Q328_R1_C6'),
#   (0.8101556301116943, 4, 2, 'Q328_R1_C5'),
#   (0.681939959526062, 3, 0, 'Q328_R1_C4'),
#   (0.5424706339836121, 8, 0, 'Q328_R1_C9'),
#   (0.540515661239624, 9, 0, 'Q328_R1_C10'),
#   (0.5022057294845581, 7, 2, 'Q328_R1_C8'),
#   (0.42206311225891113, 1, 0, 'Q328_R1_C2'),
#   (0.3887472450733185, 2, 2, 'Q328_R1_C3'),
#   (0.3290903568267822, 6, 0, 'Q328_R1_C7'),
#   (0.28899478912353516, 0, 2, 'Q328_R1_C1')],
#  [(0.9176422357559204, 0, 2, 'Q328_R22_C1'),
#   (0.8745689392089844, 9, 2, 'Q328_R22_C10'),
#   (0.8726402521133423, 2, 2, 'Q328_R22_C3'),
#   (0.858615517616272, 6, 0, 'Q328_R22_C7'),
#   (0.8536550998687744, 3, 2, 'Q328_R22_C4'),
#   (0.8445428609848022, 5, 0, 'Q328_R22_C6'),
#   (0.8041236400604248, 7, 1, 'Q328_R22_C8'),
#   (0.720655620098114, 1, 2, 'Q328_R22_C2'),
#   (0.6937492489814758, 4, 2, 'Q328_R22_C5'),
#   (0.4332064390182495, 8, 0, 'Q328_R22_C9')],
#  [(0.8403799533843994, 2, 2, 'Q328_R23_C3'),
#   (0.8089772462844849, 8, 0, 'Q328_R23_C9'),
#   (0.7897239923477173, 0, 2, 'Q328_R23_C1'),
#   (0.7815711498260498, 1, 2, 'Q328_R23_C2'),
#   (0.6827574968338013, 5, 1, 'Q328_R23_C6'),
#   (0.6703737378120422, 7, 0, 'Q328_R23_C8'),
#   (0.6349862813949585, 3, 2, 'Q328_R23_C4'),
#   (0.6143574714660645, 6, 0, 'Q328_R23_C7'),
#   (0.39340025186538696, 9, 0, 'Q328_R23_C10'),
#   (0.158473938703537, 4, 0, 'Q328_R23_C5')],
#  [(0.8156230449676514, 7, 0, 'Q329_R8_C8'),
#   (0.8088181018829346, 4, 0, 'Q329_R8_C5'),
#   (0.3167596161365509, 8, 1, 'Q329_R8_C9'),
#   (0.23231777548789978, 6, 1, 'Q329_R8_C7'),
#   (0.21030376851558685, 0, 0, 'Q329_R8_C1'),
#   (0.1934664249420166, 2, 0, 'Q329_R8_C3'),
#   (0.1394573450088501, 3, 0, 'Q329_R8_C4'),
#   (0.12601405382156372, 5, 0, 'Q329_R8_C6'),
#   (0.12112590670585632, 1, 0, 'Q329_R8_C2'),
#   (0.0791073590517044, 9, 0, 'Q329_R8_C10')],
#  [(0.9178764820098877, 3, 2, 'Q329_R21_C4'),
#   (0.9102722406387329, 9, 1, 'Q329_R21_C10'),
#   (0.8644062280654907, 0, 0, 'Q329_R21_C1'),
#   (0.8580632209777832, 7, 0, 'Q329_R21_C8'),
#   (0.8349602222442627, 6, 0, 'Q329_R21_C7'),
#   (0.8304481506347656, 1, 0, 'Q329_R21_C2'),
#   (0.8303577899932861, 4, 0, 'Q329_R21_C5'),
#   (0.751884400844574, 8, 0, 'Q329_R21_C9'),
#   (0.6192440390586853, 2, 0, 'Q329_R21_C3'),
#   (0.3510493040084839, 5, 0, 'Q329_R21_C6')],
#  [(0.8625240325927734, 7, 2, 'Q329_R62_C8'),
#   (0.7720228433609009, 0, 2, 'Q329_R62_C1'),
#   (0.694111168384552, 9, 2, 'Q329_R62_C10'),
#   (0.3072618544101715, 8, 0, 'Q329_R62_C9'),
#   (0.2918151021003723, 5, 0, 'Q329_R62_C6'),
#   (0.16710667312145233, 6, 2, 'Q329_R62_C7'),
#   (0.15504227578639984, 4, 0, 'Q329_R62_C5'),
#   (0.13436783850193024, 1, 0, 'Q329_R62_C2'),
#   (0.05496227741241455, 3, 0, 'Q329_R62_C4'),
#   (0.05468282103538513, 2, 0, 'Q329_R62_C3')],
#  [(0.9251770973205566, 6, 2, 'Q329_R73_C7'),
#   (0.9240567684173584, 2, 2, 'Q329_R73_C3'),
#   (0.9217232465744019, 7, 1, 'Q329_R73_C8'),
#   (0.9192264080047607, 0, 1, 'Q329_R73_C1'),
#   (0.912554144859314, 3, 2, 'Q329_R73_C4'),
#   (0.8611382246017456, 5, 0, 'Q329_R73_C6'),
#   (0.8309142589569092, 9, 1, 'Q329_R73_C10'),
#   (0.6111224293708801, 1, 0, 'Q329_R73_C2'),
#   (0.1489311009645462, 8, 0, 'Q329_R73_C9'),
#   (0.11121058464050293, 4, 0, 'Q329_R73_C5')],
#  [(0.9132702350616455, 3, 2, 'Q329_R74_C4'),
#   (0.892668604850769, 1, 2, 'Q329_R74_C2'),
#   (0.8555895090103149, 9, 2, 'Q329_R74_C10'),
#   (0.7702717781066895, 6, 0, 'Q329_R74_C7'),
#   (0.7092820405960083, 7, 2, 'Q329_R74_C8'),
#   (0.7046810388565063, 4, 2, 'Q329_R74_C5'),
#   (0.600464940071106, 2, 2, 'Q329_R74_C3'),
#   (0.5243557691574097, 5, 2, 'Q329_R74_C6'),
#   (0.3149280548095703, 0, 2, 'Q329_R74_C1'),
#   (0.1510802060365677, 8, 0, 'Q329_R74_C9')],
#  [(0.8939831256866455, 4, 2, 'Q329_R75_C5'),
#   (0.7916853427886963, 8, 1, 'Q329_R75_C9'),
#   (0.7536398768424988, 6, 2, 'Q329_R75_C7'),
#   (0.727312445640564, 7, 2, 'Q329_R75_C8'),
#   (0.6648266315460205, 9, 2, 'Q329_R75_C10'),
#   (0.5533974766731262, 0, 2, 'Q329_R75_C1'),
#   (0.31087327003479004, 3, 2, 'Q329_R75_C4'),
#   (0.27751994132995605, 5, 0, 'Q329_R75_C6'),
#   (0.24371597170829773, 2, 1, 'Q329_R75_C3'),
#   (0.20225660502910614, 1, 0, 'Q329_R75_C2')],
#  [(0.9066393375396729, 8, 2, 'Q330_R6_C9'),
#   (0.7929465770721436, 5, 1, 'Q330_R6_C6'),
#   (0.7257448434829712, 6, 0, 'Q330_R6_C7'),
#   (0.49682384729385376, 4, 2, 'Q330_R6_C5'),
#   (0.47048091888427734, 2, 0, 'Q330_R6_C3'),
#   (0.4658673405647278, 3, 2, 'Q330_R6_C4'),
#   (0.19186794757843018, 1, 2, 'Q330_R6_C2'),
#   (0.13340455293655396, 9, 0, 'Q330_R6_C10'),
#   (0.0904770940542221, 7, 0, 'Q330_R6_C8'),
#   (0.07496793568134308, 0, 2, 'Q330_R6_C1')],
#  [(0.9043432474136353, 2, 2, 'Q330_R8_C3'),
#   (0.8813686370849609, 3, 2, 'Q330_R8_C4'),
#   (0.8645949363708496, 4, 2, 'Q330_R8_C5'),
#   (0.7990342378616333, 1, 2, 'Q330_R8_C2'),
#   (0.6421625018119812, 0, 2, 'Q330_R8_C1'),
#   (0.4324956238269806, 6, 2, 'Q330_R8_C7'),
#   (0.37328776717185974, 5, 2, 'Q330_R8_C6'),
#   (0.34426361322402954, 8, 2, 'Q330_R8_C9'),
#   (0.26776719093322754, 7, 2, 'Q330_R8_C8'),
#   (0.2499348223209381, 9, 2, 'Q330_R8_C10')],
#  [(0.9702185392379761, 4, 2, 'Q330_R12_C5'),
#   (0.9614212512969971, 7, 2, 'Q330_R12_C8'),
#   (0.8963271379470825, 8, 0, 'Q330_R12_C9'),
#   (0.6347593665122986, 5, 2, 'Q330_R12_C6'),
#   (0.5979863405227661, 9, 1, 'Q330_R12_C10'),
#   (0.42720693349838257, 1, 0, 'Q330_R12_C2'),
#   (0.17098847031593323, 2, 2, 'Q330_R12_C3'),
#   (0.09297172725200653, 0, 0, 'Q330_R12_C1'),
#   (0.08897063136100769, 6, 0, 'Q330_R12_C7'),
#   (0.06320390105247498, 3, 0, 'Q330_R12_C4')],
#  [(0.9161621332168579, 1, 2, 'Q330_R22_C2'),
#   (0.8712506294250488, 9, 1, 'Q330_R22_C10'),
#   (0.8305635452270508, 7, 1, 'Q330_R22_C8'),
#   (0.8039171695709229, 5, 0, 'Q330_R22_C6'),
#   (0.7418689727783203, 6, 0, 'Q330_R22_C7'),
#   (0.7028945684432983, 4, 1, 'Q330_R22_C5'),
#   (0.6000001430511475, 0, 2, 'Q330_R22_C1'),
#   (0.26981568336486816, 3, 2, 'Q330_R22_C4'),
#   (0.19136734306812286, 2, 1, 'Q330_R22_C3'),
#   (0.13572724163532257, 8, 0, 'Q330_R22_C9')],
#  [(0.9929207563400269, 8, 1, 'Q330_R44_C9'),
#   (0.9843896627426147, 7, 1, 'Q330_R44_C8'),
#   (0.9269182682037354, 6, 1, 'Q330_R44_C7'),
#   (0.895490288734436, 4, 1, 'Q330_R44_C5'),
#   (0.8903032541275024, 5, 1, 'Q330_R44_C6'),
#   (0.8254998922348022, 9, 1, 'Q330_R44_C10'),
#   (0.7785763740539551, 1, 1, 'Q330_R44_C2'),
#   (0.4846750497817993, 0, 0, 'Q330_R44_C1'),
#   (0.24897915124893188, 3, 0, 'Q330_R44_C4'),
#   (0.21322520077228546, 2, 0, 'Q330_R44_C3')],
#  [(1.0057456493377686, 3, 2, 'Q330_R53_C4'),
#   (0.8844950199127197, 1, 2, 'Q330_R53_C2'),
#   (0.8045400381088257, 6, 1, 'Q330_R53_C7'),
#   (0.7113155126571655, 9, 0, 'Q330_R53_C10'),
#   (0.5630837678909302, 2, 0, 'Q330_R53_C3'),
#   (0.5504336357116699, 8, 1, 'Q330_R53_C9'),
#   (0.28861525654792786, 5, 0, 'Q330_R53_C6'),
#   (0.2256363481283188, 0, 0, 'Q330_R53_C1'),
#   (0.13959836959838867, 7, 0, 'Q330_R53_C8'),
#   (0.10993263125419617, 4, 0, 'Q330_R53_C5')],
#  [(0.9167256355285645, 5, 0, 'Q330_R89_C6'),
#   (0.7680743336677551, 9, 2, 'Q330_R89_C10'),
#   (0.574610710144043, 7, 2, 'Q330_R89_C8'),
#   (0.4733676314353943, 1, 2, 'Q330_R89_C2'),
#   (0.4733676314353943, 0, 2, 'Q330_R89_C1'),
#   (0.4250389039516449, 6, 0, 'Q330_R89_C7'),
#   (0.23785367608070374, 3, 2, 'Q330_R89_C4'),
#   (0.2223062515258789, 4, 0, 'Q330_R89_C5'),
#   (0.17686454951763153, 8, 0, 'Q330_R89_C9'),
#   (0.06122559309005737, 2, 0, 'Q330_R89_C3')],
#  [(0.9294114112854004, 1, 2, 'Q330_R96_C2'),
#   (0.8928380012512207, 2, 2, 'Q330_R96_C3'),
#   (0.7713922262191772, 3, 0, 'Q330_R96_C4'),
#   (0.7579746246337891, 9, 2, 'Q330_R96_C10'),
#   (0.22436381876468658, 7, 2, 'Q330_R96_C8'),
#   (0.21933770179748535, 4, 0, 'Q330_R96_C5'),
#   (0.1918177306652069, 0, 1, 'Q330_R96_C1'),
#   (0.15329624712467194, 8, 0, 'Q330_R96_C9'),
#   (0.11436067521572113, 5, 0, 'Q330_R96_C6'),
#   (0.09997883439064026, 6, 0, 'Q330_R96_C7')],
#  [(0.6925585865974426, 9, 2, 'Q331_R1_C10'),
#   (0.4287973642349243, 4, 0, 'Q331_R1_C5'),
#   (0.31624236702919006, 5, 0, 'Q331_R1_C6'),
#   (0.16334281861782074, 6, 0, 'Q331_R1_C7'),
#   (0.1570868343114853, 7, 0, 'Q331_R1_C8'),
#   (0.13340719044208527, 3, 0, 'Q331_R1_C4'),
#   (0.11400969326496124, 1, 0, 'Q331_R1_C2'),
#   (0.10950548946857452, 2, 0, 'Q331_R1_C3'),
#   (0.10172620415687561, 0, 0, 'Q331_R1_C1'),
#   (0.0961848795413971, 8, 0, 'Q331_R1_C9')],
#  [(0.9460612535476685, 7, 1, 'Q331_R11_C8'),
#   (0.937292218208313, 2, 2, 'Q331_R11_C3'),
#   (0.922508955001831, 0, 2, 'Q331_R11_C1'),
#   (0.9188410043716431, 6, 0, 'Q331_R11_C7'),
#   (0.9171832799911499, 9, 1, 'Q331_R11_C10'),
#   (0.9137225151062012, 8, 2, 'Q331_R11_C9'),
#   (0.8832180500030518, 3, 1, 'Q331_R11_C4'),
#   (0.8456217050552368, 4, 2, 'Q331_R11_C5'),
#   (0.8280314207077026, 1, 2, 'Q331_R11_C2'),
#   (0.7913574576377869, 5, 2, 'Q331_R11_C6')],
#  [(0.8838862180709839, 5, 1, 'Q331_R23_C6'),
#   (0.8797380924224854, 2, 1, 'Q331_R23_C3'),
#   (0.8774996995925903, 4, 0, 'Q331_R23_C5'),
#   (0.8374111652374268, 7, 2, 'Q331_R23_C8'),
#   (0.8332149982452393, 3, 0, 'Q331_R23_C4'),
#   (0.7128461599349976, 8, 0, 'Q331_R23_C9'),
#   (0.6801871657371521, 0, 0, 'Q331_R23_C1'),
#   (0.39484405517578125, 1, 0, 'Q331_R23_C2'),
#   (0.21154296398162842, 9, 0, 'Q331_R23_C10'),
#   (0.16212792694568634, 6, 0, 'Q331_R23_C7')],
#  [(0.8755836486816406, 4, 0, 'Q331_R40_C5'),
#   (0.8702911138534546, 2, 2, 'Q331_R40_C3'),
#   (0.8649313449859619, 1, 2, 'Q331_R40_C2'),
#   (0.8408305644989014, 8, 0, 'Q331_R40_C9'),
#   (0.28229835629463196, 9, 0, 'Q331_R40_C10'),
#   (0.19597622752189636, 0, 1, 'Q331_R40_C1'),
#   (0.11914774775505066, 6, 0, 'Q331_R40_C7'),
#   (0.10631053149700165, 7, 0, 'Q331_R40_C8'),
#   (0.09997272491455078, 5, 0, 'Q331_R40_C6'),
#   (0.09191727638244629, 3, 0, 'Q331_R40_C4')],
#  [(0.9732513427734375, 4, 2, 'Q332_R2_C5'),
#   (0.9551517963409424, 2, 2, 'Q332_R2_C3'),
#   (0.9192367792129517, 0, 2, 'Q332_R2_C1'),
#   (0.7798315286636353, 5, 2, 'Q332_R2_C6'),
#   (0.6887321472167969, 7, 2, 'Q332_R2_C8'),
#   (0.5671339631080627, 3, 2, 'Q332_R2_C4'),
#   (0.5135914087295532, 9, 0, 'Q332_R2_C10'),
#   (0.2607126235961914, 6, 0, 'Q332_R2_C7'),
#   (0.08342505991458893, 1, 0, 'Q332_R2_C2'),
#   (-0.009206444025039673, 8, 0, 'Q332_R2_C9')],
#  [(1.0023542642593384, 0, 2, 'Q332_R15_C1'),
#   (0.9464054107666016, 2, 2, 'Q332_R15_C3'),
#   (0.9074016809463501, 1, 2, 'Q332_R15_C2'),
#   (0.16685426235198975, 9, 0, 'Q332_R15_C10'),
#   (0.1089891642332077, 8, 0, 'Q332_R15_C9'),
#   (0.07532581686973572, 3, 0, 'Q332_R15_C4'),
#   (0.0642564594745636, 4, 0, 'Q332_R15_C5'),
#   (0.05281838774681091, 5, 0, 'Q332_R15_C6'),
#   (0.012193411588668823, 6, 0, 'Q332_R15_C7'),
#   (0.0014581680297851562, 7, 0, 'Q332_R15_C8')],
#  [(0.8626153469085693, 0, 0, 'Q332_R26_C1'),
#   (0.8273764848709106, 1, 0, 'Q332_R26_C2'),
#   (0.6692330837249756, 8, 0, 'Q332_R26_C9'),
#   (0.5154200792312622, 2, 0, 'Q332_R26_C3'),
#   (0.5062693357467651, 6, 0, 'Q332_R26_C7'),
#   (0.4343545436859131, 4, 0, 'Q332_R26_C5'),
#   (0.18331237137317657, 9, 2, 'Q332_R26_C10'),
#   (0.11771664023399353, 3, 0, 'Q332_R26_C4'),
#   (0.0918436199426651, 5, 0, 'Q332_R26_C6'),
#   (0.08535772562026978, 7, 2, 'Q332_R26_C8')],
#  [(0.8370933532714844, 1, 0, 'Q332_R31_C2'),
#   (0.8355419635772705, 7, 0, 'Q332_R31_C8'),
#   (0.8035686612129211, 4, 0, 'Q332_R31_C5'),
#   (0.8035686612129211, 3, 0, 'Q332_R31_C4'),
#   (0.5955140590667725, 2, 0, 'Q332_R31_C3'),
#   (0.30468642711639404, 9, 0, 'Q332_R31_C10'),
#   (0.20294451713562012, 6, 0, 'Q332_R31_C7'),
#   (0.17053362727165222, 0, 0, 'Q332_R31_C1'),
#   (0.12543082237243652, 5, 0, 'Q332_R31_C6'),
#   (0.10451701283454895, 8, 0, 'Q332_R31_C9')],
#  [(0.9416658878326416, 0, 2, 'Q332_R36_C1'),
#   (0.9358114004135132, 5, 2, 'Q332_R36_C6'),
#   (0.8555412292480469, 1, 2, 'Q332_R36_C2'),
#   (0.8474271297454834, 9, 2, 'Q332_R36_C10'),
#   (0.8474271297454834, 8, 2, 'Q332_R36_C9'),
#   (0.8474271297454834, 7, 2, 'Q332_R36_C8'),
#   (0.8379102945327759, 4, 2, 'Q332_R36_C5'),
#   (0.4933975040912628, 3, 2, 'Q332_R36_C4'),
#   (0.27973008155822754, 2, 2, 'Q332_R36_C3'),
#   (0.12064744532108307, 6, 0, 'Q332_R36_C7')],
#  [(0.5378869771957397, 7, 0, 'Q332_R51_C8'),
#   (0.1596590280532837, 5, 2, 'Q332_R51_C6'),
#   (0.1565311849117279, 2, 2, 'Q332_R51_C3'),
#   (0.14317633211612701, 8, 0, 'Q332_R51_C9'),
#   (0.12127716839313507, 0, 2, 'Q332_R51_C1'),
#   (0.10506239533424377, 4, 2, 'Q332_R51_C5'),
#   (0.09697951376438141, 1, 2, 'Q332_R51_C2'),
#   (0.09213560819625854, 9, 0, 'Q332_R51_C10'),
#   (0.08410337567329407, 6, 2, 'Q332_R51_C7'),
#   (0.07976962625980377, 3, 2, 'Q332_R51_C4')],
#  [(0.9543279409408569, 2, 2, 'Q333_R4_C3'),
#   (0.9007422924041748, 6, 2, 'Q333_R4_C7'),
#   (0.8283385038375854, 8, 0, 'Q333_R4_C9'),
#   (0.8266466856002808, 9, 0, 'Q333_R4_C10'),
#   (0.7609565258026123, 5, 1, 'Q333_R4_C6'),
#   (0.42528173327445984, 0, 2, 'Q333_R4_C1'),
#   (0.4200654625892639, 3, 0, 'Q333_R4_C4'),
#   (0.2500462830066681, 4, 2, 'Q333_R4_C5'),
#   (0.18247368931770325, 1, 2, 'Q333_R4_C2'),
#   (0.1658133566379547, 7, 0, 'Q333_R4_C8')],
#  [(1.0719977617263794, 1, 2, 'Q333_R27_C2'),
#   (1.0428688526153564, 0, 2, 'Q333_R27_C1'),
#   (1.0212492942810059, 4, 2, 'Q333_R27_C5'),
#   (0.9931774139404297, 7, 2, 'Q333_R27_C8'),
#   (0.9533170461654663, 5, 2, 'Q333_R27_C6'),
#   (0.9429514408111572, 6, 2, 'Q333_R27_C7'),
#   (0.9347085952758789, 3, 1, 'Q333_R27_C4'),
#   (0.8822659254074097, 8, 2, 'Q333_R27_C9'),
#   (0.8277859687805176, 9, 0, 'Q333_R27_C10'),
#   (0.7294309139251709, 2, 0, 'Q333_R27_C3')],
#  [(0.9077484607696533, 4, 2, 'Q333_R34_C5'),
#   (0.8295044898986816, 6, 2, 'Q333_R34_C7'),
#   (0.7850443124771118, 7, 1, 'Q333_R34_C8'),
#   (0.7683042287826538, 2, 2, 'Q333_R34_C3'),
#   (0.7174745798110962, 0, 2, 'Q333_R34_C1'),
#   (0.5800349116325378, 1, 2, 'Q333_R34_C2'),
#   (0.17453819513320923, 8, 0, 'Q333_R34_C9'),
#   (0.11614936590194702, 3, 0, 'Q333_R34_C4'),
#   (0.11127501726150513, 5, 0, 'Q333_R34_C6'),
#   (0.09109072387218475, 9, 0, 'Q333_R34_C10')],
#  [(0.9962530136108398, 5, 2, 'Q333_R49_C6'),
#   (0.9792519807815552, 8, 2, 'Q333_R49_C9'),
#   (0.7932878732681274, 9, 1, 'Q333_R49_C10'),
#   (0.7859549522399902, 3, 2, 'Q333_R49_C4'),
#   (0.7537297606468201, 4, 2, 'Q333_R49_C5'),
#   (0.7491366863250732, 7, 1, 'Q333_R49_C8'),
#   (0.6039218902587891, 0, 1, 'Q333_R49_C1'),
#   (0.5843745470046997, 6, 2, 'Q333_R49_C7'),
#   (0.41649481654167175, 2, 1, 'Q333_R49_C3'),
#   (0.20421957969665527, 1, 1, 'Q333_R49_C2')],
#  [(0.9505853652954102, 2, 2, 'Q334_R1_C3'),
#   (0.8602960109710693, 1, 2, 'Q334_R1_C2'),
#   (0.6748144030570984, 5, 1, 'Q334_R1_C6'),
#   (0.45689865946769714, 9, 0, 'Q334_R1_C10'),
#   (0.25781911611557007, 3, 0, 'Q334_R1_C4'),
#   (0.2046205699443817, 0, 2, 'Q334_R1_C1'),
#   (0.19721487164497375, 6, 0, 'Q334_R1_C7'),
#   (0.14955441653728485, 8, 0, 'Q334_R1_C9'),
#   (0.12965184450149536, 4, 0, 'Q334_R1_C5'),
#   (0.05536434054374695, 7, 0, 'Q334_R1_C8')],
#  [(0.9605189561843872, 2, 2, 'Q334_R38_C3'),
#   (0.9395722150802612, 5, 2, 'Q334_R38_C6'),
#   (0.7410930395126343, 0, 2, 'Q334_R38_C1'),
#   (0.6626346111297607, 3, 1, 'Q334_R38_C4'),
#   (0.641792893409729, 9, 1, 'Q334_R38_C10'),
#   (0.32896333932876587, 7, 0, 'Q334_R38_C8'),
#   (0.12646536529064178, 6, 0, 'Q334_R38_C7'),
#   (0.10233612358570099, 8, 0, 'Q334_R38_C9'),
#   (0.048595279455184937, 4, 0, 'Q334_R38_C5'),
#   (0.022120296955108643, 1, 0, 'Q334_R38_C2')],
#  [(0.9257280826568604, 5, 2, 'Q335_R1_C6'),
#   (0.8270276784896851, 4, 0, 'Q335_R1_C5'),
#   (0.7583414316177368, 1, 0, 'Q335_R1_C2'),
#   (0.63458251953125, 6, 2, 'Q335_R1_C7'),
#   (0.42343616485595703, 8, 2, 'Q335_R1_C9'),
#   (0.40676355361938477, 0, 2, 'Q335_R1_C1'),
#   (0.3982639014720917, 9, 0, 'Q335_R1_C10'),
#   (0.2339491993188858, 2, 0, 'Q335_R1_C3'),
#   (0.1452140063047409, 3, 0, 'Q335_R1_C4'),
#   (0.13033579289913177, 7, 0, 'Q335_R1_C8')],
#  [(0.9153941869735718, 5, 2, 'Q335_R7_C6'),
#   (0.8238420486450195, 9, 0, 'Q335_R7_C10'),
#   (0.8003848195075989, 3, 1, 'Q335_R7_C4'),
#   (0.7658126354217529, 2, 2, 'Q335_R7_C3'),
#   (0.37061959505081177, 1, 0, 'Q335_R7_C2'),
#   (0.2921183109283447, 7, 2, 'Q335_R7_C8'),
#   (0.24719735980033875, 4, 0, 'Q335_R7_C5'),
#   (0.20361551642417908, 8, 0, 'Q335_R7_C9'),
#   (0.16646717488765717, 0, 2, 'Q335_R7_C1'),
#   (0.1160132884979248, 6, 0, 'Q335_R7_C7')],
#  [(0.9879007339477539, 0, 2, 'Q335_R9_C1'),
#   (0.9131040573120117, 8, 2, 'Q335_R9_C9'),
#   (0.9073866605758667, 4, 2, 'Q335_R9_C5'),
#   (0.8672424554824829, 3, 2, 'Q335_R9_C4'),
#   (0.8284962177276611, 9, 0, 'Q335_R9_C10'),
#   (0.716372013092041, 6, 0, 'Q335_R9_C7'),
#   (0.4635695815086365, 1, 0, 'Q335_R9_C2'),
#   (0.436268150806427, 2, 0, 'Q335_R9_C3'),
#   (0.21438762545585632, 5, 0, 'Q335_R9_C6'),
#   (0.09754139184951782, 7, 0, 'Q335_R9_C8')],
#  [(0.9825198650360107, 7, 2, 'Q335_R10_C8'),
#   (0.9583449363708496, 4, 1, 'Q335_R10_C5'),
#   (0.951873779296875, 2, 2, 'Q335_R10_C3'),
#   (0.9102447032928467, 9, 2, 'Q335_R10_C10'),
#   (0.8357598781585693, 8, 2, 'Q335_R10_C9'),
#   (0.8290380239486694, 5, 2, 'Q335_R10_C6'),
#   (0.5847619771957397, 0, 2, 'Q335_R10_C1'),
#   (0.17309632897377014, 1, 0, 'Q335_R10_C2'),
#   (0.11982762813568115, 3, 0, 'Q335_R10_C4'),
#   (0.08827550709247589, 6, 0, 'Q335_R10_C7')],
#  [(1.0530331134796143, 4, 2, 'Q335_R19_C5'),
#   (0.983243465423584, 9, 2, 'Q335_R19_C10'),
#   (0.9503086805343628, 0, 2, 'Q335_R19_C1'),
#   (0.8936870098114014, 1, 2, 'Q335_R19_C2'),
#   (0.8706456422805786, 3, 2, 'Q335_R19_C4'),
#   (0.44593438506126404, 7, 0, 'Q335_R19_C8'),
#   (0.4290938973426819, 2, 0, 'Q335_R19_C3'),
#   (0.10774308443069458, 6, 0, 'Q335_R19_C7'),
#   (0.09665791690349579, 8, 0, 'Q335_R19_C9'),
#   (0.07922212779521942, 5, 0, 'Q335_R19_C6')],
#  [(0.4977421462535858, 1, 0, 'Q336_R1_C2'),
#   (0.34233155846595764, 9, 2, 'Q336_R1_C10'),
#   (0.34087076783180237, 5, 0, 'Q336_R1_C6'),
#   (0.25078773498535156, 0, 2, 'Q336_R1_C1'),
#   (0.21465155482292175, 3, 0, 'Q336_R1_C4'),
#   (0.21170178055763245, 2, 0, 'Q336_R1_C3'),
#   (0.1581365466117859, 8, 0, 'Q336_R1_C9'),
#   (0.09697352349758148, 4, 2, 'Q336_R1_C5'),
#   (0.07534042000770569, 6, 0, 'Q336_R1_C7'),
#   (0.06888708472251892, 7, 0, 'Q336_R1_C8')],
#  [(0.5960652828216553, 5, 0, 'Q336_R6_C6'),
#   (0.4641173779964447, 1, 0, 'Q336_R6_C2'),
#   (0.4640689492225647, 3, 1, 'Q336_R6_C4'),
#   (0.4217776358127594, 7, 0, 'Q336_R6_C8'),
#   (0.2727864980697632, 9, 2, 'Q336_R6_C10'),
#   (0.16760854423046112, 2, 1, 'Q336_R6_C3'),
#   (0.16513681411743164, 8, 0, 'Q336_R6_C9'),
#   (0.08219452202320099, 0, 0, 'Q336_R6_C1'),
#   (0.07261429727077484, 6, 0, 'Q336_R6_C7'),
#   (0.0665304958820343, 4, 0, 'Q336_R6_C5')],
#  [(0.3817373514175415, 3, 1, 'Q336_R13_C4'),
#   (0.32578244805336, 1, 2, 'Q336_R13_C2'),
#   (0.1795331984758377, 8, 2, 'Q336_R13_C9'),
#   (0.14684011042118073, 0, 0, 'Q336_R13_C1'),
#   (0.14262214303016663, 5, 0, 'Q336_R13_C6'),
#   (0.12491148710250854, 9, 2, 'Q336_R13_C10'),
#   (0.09362311661243439, 7, 2, 'Q336_R13_C8'),
#   (0.09024536609649658, 2, 1, 'Q336_R13_C3'),
#   (0.07780560851097107, 4, 0, 'Q336_R13_C5'),
#   (0.07688738405704498, 6, 0, 'Q336_R13_C7')],
#  [(0.842789888381958, 4, 0, 'Q336_R24_C5'),
#   (0.810697078704834, 5, 2, 'Q336_R24_C6'),
#   (0.7922890782356262, 3, 1, 'Q336_R24_C4'),
#   (0.7586827278137207, 7, 2, 'Q336_R24_C8'),
#   (0.6564289331436157, 1, 2, 'Q336_R24_C2'),
#   (0.6009904146194458, 9, 2, 'Q336_R24_C10'),
#   (0.5107600688934326, 6, 2, 'Q336_R24_C7'),
#   (0.3006458878517151, 8, 0, 'Q336_R24_C9'),
#   (0.1468699723482132, 2, 0, 'Q336_R24_C3'),
#   (0.1229492723941803, 0, 2, 'Q336_R24_C1')],
#  [(0.9666986465454102, 0, 2, 'Q336_R37_C1'),
#   (0.8716533184051514, 4, 2, 'Q336_R37_C5'),
#   (0.8515775203704834, 5, 1, 'Q336_R37_C6'),
#   (0.7017309069633484, 8, 0, 'Q336_R37_C9'),
#   (0.5573095679283142, 2, 0, 'Q336_R37_C3'),
#   (0.41759514808654785, 6, 1, 'Q336_R37_C7'),
#   (0.16822081804275513, 3, 0, 'Q336_R37_C4'),
#   (0.1650836169719696, 9, 0, 'Q336_R37_C10'),
#   (0.07481379806995392, 1, 0, 'Q336_R37_C2'),
#   (0.07259927690029144, 7, 0, 'Q336_R37_C8')],
#  [(0.7862102389335632, 0, 1, 'Q336_R40_C1'),
#   (0.6967564821243286, 3, 2, 'Q336_R40_C4'),
#   (0.3645259141921997, 4, 0, 'Q336_R40_C5'),
#   (0.33286306262016296, 8, 0, 'Q336_R40_C9'),
#   (0.22594740986824036, 6, 0, 'Q336_R40_C7'),
#   (0.14642947912216187, 9, 0, 'Q336_R40_C10'),
#   (0.14616169035434723, 5, 0, 'Q336_R40_C6'),
#   (0.12575480341911316, 2, 0, 'Q336_R40_C3'),
#   (0.09411005675792694, 7, 0, 'Q336_R40_C8'),
#   (0.08499452471733093, 1, 2, 'Q336_R40_C2')],
#  [(0.7746403217315674, 0, 2, 'Q337_R1_C1'),
#   (0.4837501049041748, 1, 0, 'Q337_R1_C2'),
#   (0.4582762122154236, 6, 0, 'Q337_R1_C7'),
#   (0.3374484181404114, 5, 0, 'Q337_R1_C6'),
#   (0.2650882601737976, 9, 0, 'Q337_R1_C10'),
#   (0.24437637627124786, 3, 0, 'Q337_R1_C4'),
#   (0.18421271443367004, 2, 2, 'Q337_R1_C3'),
#   (0.14241059124469757, 8, 2, 'Q337_R1_C9'),
#   (0.07609231770038605, 4, 0, 'Q337_R1_C5'),
#   (0.0680975615978241, 7, 0, 'Q337_R1_C8')],
#  [(0.928019642829895, 2, 2, 'Q337_R4_C3'),
#   (0.8862688541412354, 1, 2, 'Q337_R4_C2'),
#   (0.8356938362121582, 7, 2, 'Q337_R4_C8'),
#   (0.3063591420650482, 4, 2, 'Q337_R4_C5'),
#   (0.2587078809738159, 5, 2, 'Q337_R4_C6'),
#   (0.23690330982208252, 6, 2, 'Q337_R4_C7'),
#   (0.22584034502506256, 3, 2, 'Q337_R4_C4'),
#   (0.1560959666967392, 0, 2, 'Q337_R4_C1'),
#   (0.0877334326505661, 9, 0, 'Q337_R4_C10'),
#   (0.03431275486946106, 8, 0, 'Q337_R4_C9')],
#  [(0.8478294610977173, 2, 2, 'Q337_R16_C3'),
#   (0.8461939096450806, 9, 1, 'Q337_R16_C10'),
#   (0.8225858211517334, 5, 2, 'Q337_R16_C6'),
#   (0.8156596422195435, 3, 2, 'Q337_R16_C4'),
#   (0.7914249300956726, 0, 2, 'Q337_R16_C1'),
#   (0.7579096555709839, 6, 1, 'Q337_R16_C7'),
#   (0.4033391773700714, 4, 0, 'Q337_R16_C5'),
#   (0.18889081478118896, 8, 0, 'Q337_R16_C9'),
#   (0.10339927673339844, 1, 0, 'Q337_R16_C2'),
#   (0.09208700060844421, 7, 0, 'Q337_R16_C8')],
#  [(0.851951003074646, 1, 0, 'Q337_R19_C2'),
#   (0.8307284116744995, 9, 2, 'Q337_R19_C10'),
#   (0.8277345895767212, 4, 2, 'Q337_R19_C5'),
#   (0.6378660202026367, 7, 1, 'Q337_R19_C8'),
#   (0.3756442070007324, 0, 1, 'Q337_R19_C1'),
#   (0.3437645733356476, 8, 1, 'Q337_R19_C9'),
#   (0.28220468759536743, 2, 2, 'Q337_R19_C3'),
#   (0.26550325751304626, 3, 2, 'Q337_R19_C4'),
#   (0.1853426992893219, 6, 2, 'Q337_R19_C7'),
#   (0.14649127423763275, 5, 1, 'Q337_R19_C6')],
#  [(0.7534847259521484, 4, 0, 'Q337_R21_C5'),
#   (0.5968190431594849, 6, 1, 'Q337_R21_C7'),
#   (0.5239869356155396, 1, 1, 'Q337_R21_C2'),
#   (0.5124061107635498, 5, 0, 'Q337_R21_C6'),
#   (0.5088163614273071, 3, 2, 'Q337_R21_C4'),
#   (0.2174161970615387, 9, 1, 'Q337_R21_C10'),
#   (0.12832695245742798, 8, 1, 'Q337_R21_C9'),
#   (0.08668145537376404, 0, 0, 'Q337_R21_C1'),
#   (0.0667632520198822, 2, 1, 'Q337_R21_C3'),
#   (0.051741570234298706, 7, 1, 'Q337_R21_C8')],
#  [(0.7521467804908752, 7, 1, 'Q337_R36_C8'),
#   (0.48687565326690674, 2, 0, 'Q337_R36_C3'),
#   (0.23485469818115234, 6, 0, 'Q337_R36_C7'),
#   (0.19952920079231262, 3, 0, 'Q337_R36_C4'),
#   (0.1847761869430542, 0, 0, 'Q337_R36_C1'),
#   (0.15099824965000153, 1, 0, 'Q337_R36_C2'),
#   (0.12401145696640015, 9, 2, 'Q337_R36_C10'),
#   (0.0897446870803833, 4, 0, 'Q337_R36_C5'),
#   (0.08040039241313934, 5, 0, 'Q337_R36_C6'),
#   (0.06312331557273865, 8, 0, 'Q337_R36_C9')],
#  [(0.9626545906066895, 8, 1, 'Q338_R2_C9'),
#   (0.8575513362884521, 7, 1, 'Q338_R2_C8'),
#   (0.8322979211807251, 3, 1, 'Q338_R2_C4'),
#   (0.8054288625717163, 9, 1, 'Q338_R2_C10'),
#   (0.5607514381408691, 6, 0, 'Q338_R2_C7'),
#   (0.49029475450515747, 2, 2, 'Q338_R2_C3'),
#   (0.24721170961856842, 4, 2, 'Q338_R2_C5'),
#   (0.2100587636232376, 0, 2, 'Q338_R2_C1'),
#   (0.20707443356513977, 1, 2, 'Q338_R2_C2'),
#   (0.1977939009666443, 5, 2, 'Q338_R2_C6')],
#  [(0.8502745628356934, 7, 0, 'Q338_R11_C8'),
#   (0.8468482494354248, 1, 1, 'Q338_R11_C2'),
#   (0.819684624671936, 9, 2, 'Q338_R11_C10'),
#   (0.7533631920814514, 0, 0, 'Q338_R11_C1'),
#   (0.6694741249084473, 4, 1, 'Q338_R11_C5'),
#   (0.28604456782341003, 3, 0, 'Q338_R11_C4'),
#   (0.28604456782341003, 2, 0, 'Q338_R11_C3'),
#   (0.2549275755882263, 8, 2, 'Q338_R11_C9'),
#   (0.11444993317127228, 5, 0, 'Q338_R11_C6'),
#   (0.10182662308216095, 6, 0, 'Q338_R11_C7')],
#  [(0.8749797344207764, 0, 1, 'Q338_R27_C1'),
#   (0.41051942110061646, 4, 0, 'Q338_R27_C5'),
#   (0.27529090642929077, 5, 0, 'Q338_R27_C6'),
#   (0.268382728099823, 3, 2, 'Q338_R27_C4'),
#   (0.2099332958459854, 6, 0, 'Q338_R27_C7'),
#   (0.20215487480163574, 9, 2, 'Q338_R27_C10'),
#   (0.1302122324705124, 7, 0, 'Q338_R27_C8'),
#   (0.128204807639122, 1, 0, 'Q338_R27_C2'),
#   (0.09918099641799927, 8, 0, 'Q338_R27_C9'),
#   (0.08754613995552063, 2, 0, 'Q338_R27_C3')],
#  [(0.9359924793243408, 6, 2, 'Q338_R30_C7'),
#   (0.6831871271133423, 7, 2, 'Q338_R30_C8'),
#   (0.5783882141113281, 3, 1, 'Q338_R30_C4'),
#   (0.5349270701408386, 1, 2, 'Q338_R30_C2'),
#   (0.4528171718120575, 0, 1, 'Q338_R30_C1'),
#   (0.3085848093032837, 9, 1, 'Q338_R30_C10'),
#   (0.29859083890914917, 4, 1, 'Q338_R30_C5'),
#   (0.15537652373313904, 2, 1, 'Q338_R30_C3'),
#   (0.14951497316360474, 5, 1, 'Q338_R30_C6'),
#   (0.06614893674850464, 8, 0, 'Q338_R30_C9')],
#  [(0.9301801919937134, 1, 2, 'Q338_R34_C2'),
#   (0.8120478391647339, 0, 2, 'Q338_R34_C1'),
#   (0.713584840297699, 8, 0, 'Q338_R34_C9'),
#   (0.46190276741981506, 4, 0, 'Q338_R34_C5'),
#   (0.40994036197662354, 3, 0, 'Q338_R34_C4'),
#   (0.28661006689071655, 6, 0, 'Q338_R34_C7'),
#   (0.1937527060508728, 5, 0, 'Q338_R34_C6'),
#   (0.1632138043642044, 7, 0, 'Q338_R34_C8'),
#   (0.14955271780490875, 9, 2, 'Q338_R34_C10'),
#   (0.09003697335720062, 2, 0, 'Q338_R34_C3')],
#  [(0.9829056262969971, 9, 0, 'Q338_R42_C10'),
#   (0.8947674036026001, 4, 1, 'Q338_R42_C5'),
#   (0.8830736875534058, 6, 0, 'Q338_R42_C7'),
#   (0.8130766153335571, 7, 0, 'Q338_R42_C8'),
#   (0.4086073935031891, 8, 0, 'Q338_R42_C9'),
#   (0.3605283796787262, 3, 2, 'Q338_R42_C4'),
#   (0.25447648763656616, 0, 2, 'Q338_R42_C1'),
#   (0.2518555521965027, 1, 0, 'Q338_R42_C2'),
#   (0.235147625207901, 2, 0, 'Q338_R42_C3'),
#   (0.18447692692279816, 5, 0, 'Q338_R42_C6')],
#  [(0.9741798639297485, 1, 2, 'Q339_R13_C2'),
#   (0.938962459564209, 8, 2, 'Q339_R13_C9'),
#   (0.933837890625, 0, 2, 'Q339_R13_C1'),
#   (0.8477276563644409, 6, 0, 'Q339_R13_C7'),
#   (0.7079441547393799, 4, 1, 'Q339_R13_C5'),
#   (0.2052624374628067, 7, 1, 'Q339_R13_C8'),
#   (0.17068998515605927, 9, 1, 'Q339_R13_C10'),
#   (0.13033904135227203, 5, 0, 'Q339_R13_C6'),
#   (0.11070814728736877, 3, 0, 'Q339_R13_C4'),
#   (0.08521614968776703, 2, 0, 'Q339_R13_C3')],
#  [(1.0097447633743286, 8, 2, 'Q339_R26_C9'),
#   (0.9635858535766602, 9, 2, 'Q339_R26_C10'),
#   (0.8930909633636475, 0, 1, 'Q339_R26_C1'),
#   (0.8402743339538574, 3, 0, 'Q339_R26_C4'),
#   (0.364747554063797, 5, 0, 'Q339_R26_C6'),
#   (0.23210014402866364, 7, 0, 'Q339_R26_C8'),
#   (0.1986185610294342, 6, 0, 'Q339_R26_C7'),
#   (0.16160990297794342, 2, 0, 'Q339_R26_C3'),
#   (0.1068183183670044, 4, 0, 'Q339_R26_C5'),
#   (0.08725409209728241, 1, 0, 'Q339_R26_C2')],
#  [(0.9163180589675903, 2, 2, 'Q339_R35_C3'),
#   (0.85450279712677, 9, 2, 'Q339_R35_C10'),
#   (0.8229330778121948, 0, 2, 'Q339_R35_C1'),
#   (0.7579834461212158, 5, 2, 'Q339_R35_C6'),
#   (0.7527153491973877, 6, 2, 'Q339_R35_C7'),
#   (0.7443779110908508, 7, 2, 'Q339_R35_C8'),
#   (0.7365124225616455, 3, 2, 'Q339_R35_C4'),
#   (0.60789954662323, 8, 2, 'Q339_R35_C9'),
#   (0.3757803440093994, 1, 2, 'Q339_R35_C2'),
#   (0.21486268937587738, 4, 2, 'Q339_R35_C5')],
#  [(0.967528223991394, 5, 2, 'Q339_R39_C6'),
#   (0.898821234703064, 8, 2, 'Q339_R39_C9'),
#   (0.870245099067688, 7, 1, 'Q339_R39_C8'),
# ...
#   (0.22933055460453033, 3, 2, 'Q380_R45_C4'),
#   (0.18667542934417725, 9, 0, 'Q380_R45_C10'),
#   (0.06602606177330017, 6, 0, 'Q380_R45_C7')],
#  [(0.9208807945251465, 1, 2, 'Q381_R1_C2'),
#   (0.8361456394195557, 0, 2, 'Q381_R1_C1'),
#   (0.8290755748748779, 6, 2, 'Q381_R1_C7'),
#   (0.46371471881866455, 9, 2, 'Q381_R1_C10'),
#   (0.4494436979293823, 7, 0, 'Q381_R1_C8'),
#   (0.22376857697963715, 4, 0, 'Q381_R1_C5'),
#   (0.20582258701324463, 2, 0, 'Q381_R1_C3'),
#   (0.1678435504436493, 3, 0, 'Q381_R1_C4'),
#   (0.14006610214710236, 8, 0, 'Q381_R1_C9'),
#   (0.12446975708007812, 5, 0, 'Q381_R1_C6')],
#  [(0.923202395439148, 7, 2, 'Q381_R6_C8'),
#   (0.46620863676071167, 5, 2, 'Q381_R6_C6'),
#   (0.22589406371116638, 6, 0, 'Q381_R6_C7'),
#   (0.18546591699123383, 3, 0, 'Q381_R6_C4'),
#   (0.16135470569133759, 1, 0, 'Q381_R6_C2'),
#   (0.16135470569133759, 0, 0, 'Q381_R6_C1'),
#   (0.15309983491897583, 8, 0, 'Q381_R6_C9'),
#   (0.10040280222892761, 4, 0, 'Q381_R6_C5'),
#   (0.10040280222892761, 2, 0, 'Q381_R6_C3'),
#   (0.09582696855068207, 9, 0, 'Q381_R6_C10')],
#  [(0.9773737192153931, 3, 2, 'Q381_R11_C4'),
#   (0.9569166898727417, 0, 2, 'Q381_R11_C1'),
#   (0.9124393463134766, 1, 0, 'Q381_R11_C2'),
#   (0.8266032934188843, 2, 0, 'Q381_R11_C3'),
#   (0.7241744995117188, 6, 2, 'Q381_R11_C7'),
#   (0.5603737235069275, 9, 0, 'Q381_R11_C10'),
#   (0.1822892129421234, 4, 0, 'Q381_R11_C5'),
#   (0.11894699931144714, 7, 0, 'Q381_R11_C8'),
#   (0.09979653358459473, 8, 0, 'Q381_R11_C9'),
#   (0.07901817560195923, 5, 0, 'Q381_R11_C6')],
#  [(0.9767165184020996, 8, 2, 'Q381_R15_C9'),
#   (0.9756239652633667, 6, 2, 'Q381_R15_C7'),
#   (0.9351651668548584, 2, 2, 'Q381_R15_C3'),
#   (0.9250849485397339, 1, 2, 'Q381_R15_C2'),
#   (0.9185264110565186, 0, 2, 'Q381_R15_C1'),
#   (0.8820674419403076, 9, 2, 'Q381_R15_C10'),
#   (0.8435336351394653, 7, 2, 'Q381_R15_C8'),
#   (0.7151764631271362, 4, 0, 'Q381_R15_C5'),
#   (0.09458354115486145, 3, 0, 'Q381_R15_C4'),
#   (0.04582676291465759, 5, 0, 'Q381_R15_C6')],
#  [(1.0444297790527344, 2, 2, 'Q381_R18_C3'),
#   (0.9557133913040161, 4, 2, 'Q381_R18_C5'),
#   (0.9161098003387451, 9, 1, 'Q381_R18_C10'),
#   (0.5555449724197388, 5, 2, 'Q381_R18_C6'),
#   (0.35125765204429626, 6, 0, 'Q381_R18_C7'),
#   (0.28005605936050415, 3, 0, 'Q381_R18_C4'),
#   (0.21206679940223694, 7, 0, 'Q381_R18_C8'),
#   (0.08725813031196594, 0, 0, 'Q381_R18_C1'),
#   (0.0706835687160492, 1, 0, 'Q381_R18_C2'),
#   (0.03323429822921753, 8, 0, 'Q381_R18_C9')],
#  [(0.991162896156311, 1, 2, 'Q381_R19_C2'),
#   (0.6488049030303955, 6, 0, 'Q381_R19_C7'),
#   (0.5787893533706665, 3, 2, 'Q381_R19_C4'),
#   (0.5693537592887878, 9, 2, 'Q381_R19_C10'),
#   (0.559004545211792, 5, 0, 'Q381_R19_C6'),
#   (0.4408440589904785, 0, 1, 'Q381_R19_C1'),
#   (0.3257811367511749, 2, 0, 'Q381_R19_C3'),
#   (0.19720977544784546, 8, 0, 'Q381_R19_C9'),
#   (0.1894080489873886, 7, 0, 'Q381_R19_C8'),
#   (0.08686837553977966, 4, 0, 'Q381_R19_C5')],
#  [(0.9190903902053833, 0, 2, 'Q382_R3_C1'),
#   (0.8965418338775635, 1, 2, 'Q382_R3_C2'),
#   (0.89646315574646, 6, 2, 'Q382_R3_C7'),
#   (0.895431637763977, 3, 2, 'Q382_R3_C4'),
#   (0.8492826223373413, 2, 2, 'Q382_R3_C3'),
#   (0.8369461297988892, 5, 2, 'Q382_R3_C6'),
#   (0.8115953803062439, 7, 2, 'Q382_R3_C8'),
#   (0.8051340579986572, 8, 2, 'Q382_R3_C9'),
#   (0.7909632921218872, 9, 2, 'Q382_R3_C10'),
#   (0.787248432636261, 4, 2, 'Q382_R3_C5')],
#  [(0.9316340684890747, 3, 2, 'Q382_R23_C4'),
#   (0.8816801309585571, 5, 0, 'Q382_R23_C6'),
#   (0.7705541849136353, 2, 2, 'Q382_R23_C3'),
#   (0.7542077302932739, 9, 1, 'Q382_R23_C10'),
#   (0.7509214878082275, 7, 1, 'Q382_R23_C8'),
#   (0.742728590965271, 0, 0, 'Q382_R23_C1'),
#   (0.6330645680427551, 1, 0, 'Q382_R23_C2'),
#   (0.5301213264465332, 8, 0, 'Q382_R23_C9'),
#   (0.12175551056861877, 4, 0, 'Q382_R23_C5'),
#   (0.0969868004322052, 6, 1, 'Q382_R23_C7')],
#  [(0.9408730268478394, 6, 2, 'Q382_R30_C7'),
#   (0.9272670745849609, 8, 2, 'Q382_R30_C9'),
#   (0.921552300453186, 5, 2, 'Q382_R30_C6'),
#   (0.9153367280960083, 2, 2, 'Q382_R30_C3'),
#   (0.8503888845443726, 1, 2, 'Q382_R30_C2'),
#   (0.8375496864318848, 4, 2, 'Q382_R30_C5'),
#   (0.8151792287826538, 3, 2, 'Q382_R30_C4'),
#   (0.599632740020752, 7, 2, 'Q382_R30_C8'),
#   (0.5279213786125183, 0, 2, 'Q382_R30_C1'),
#   (0.21909892559051514, 9, 0, 'Q382_R30_C10')],
#  [(0.9321174621582031, 2, 2, 'Q382_R54_C3'),
#   (0.8981634378433228, 1, 2, 'Q382_R54_C2'),
#   (0.8710377216339111, 6, 1, 'Q382_R54_C7'),
#   (0.8525879383087158, 5, 2, 'Q382_R54_C6'),
#   (0.8286499977111816, 8, 2, 'Q382_R54_C9'),
#   (0.7709591388702393, 9, 2, 'Q382_R54_C10'),
#   (0.7217026948928833, 7, 2, 'Q382_R54_C8'),
#   (0.6699905395507812, 3, 2, 'Q382_R54_C4'),
#   (0.6359121799468994, 4, 1, 'Q382_R54_C5'),
#   (0.32152843475341797, 0, 2, 'Q382_R54_C1')],
#  [(0.9100643396377563, 5, 2, 'Q383_R33_C6'),
#   (0.8985179662704468, 7, 2, 'Q383_R33_C8'),
#   (0.8413095474243164, 3, 2, 'Q383_R33_C4'),
#   (0.42436280846595764, 8, 0, 'Q383_R33_C9'),
#   (0.33956336975097656, 4, 2, 'Q383_R33_C5'),
#   (0.22759631276130676, 9, 0, 'Q383_R33_C10'),
#   (0.22607535123825073, 0, 2, 'Q383_R33_C1'),
#   (0.1879960298538208, 2, 2, 'Q383_R33_C3'),
#   (0.1734088957309723, 1, 2, 'Q383_R33_C2'),
#   (0.02939501404762268, 6, 1, 'Q383_R33_C7')],
#  [(0.8537317514419556, 0, 2, 'Q383_R34_C1'),
#   (0.572331428527832, 2, 1, 'Q383_R34_C3'),
#   (0.3943682909011841, 1, 2, 'Q383_R34_C2'),
#   (0.19399341940879822, 7, 0, 'Q383_R34_C8'),
#   (0.19399341940879822, 6, 0, 'Q383_R34_C7'),
#   (0.19399341940879822, 5, 0, 'Q383_R34_C6'),
#   (0.18752795457839966, 4, 0, 'Q383_R34_C5'),
#   (0.18752795457839966, 3, 0, 'Q383_R34_C4'),
#   (0.11276163160800934, 8, 0, 'Q383_R34_C9'),
#   (0.10212649405002594, 9, 2, 'Q383_R34_C10')],
#  [(0.7690067291259766, 8, 0, 'Q383_R39_C9'),
#   (0.41011613607406616, 5, 0, 'Q383_R39_C6'),
#   (0.3272378444671631, 0, 0, 'Q383_R39_C1'),
#   (0.24667467176914215, 3, 2, 'Q383_R39_C4'),
#   (0.23880413174629211, 9, 0, 'Q383_R39_C10'),
#   (0.20766136050224304, 4, 0, 'Q383_R39_C5'),
#   (0.1598922312259674, 7, 0, 'Q383_R39_C8'),
#   (0.14986295998096466, 2, 0, 'Q383_R39_C3'),
#   (0.12584924697875977, 1, 2, 'Q383_R39_C2'),
#   (0.10908070206642151, 6, 0, 'Q383_R39_C7')],
#  [(0.9330887794494629, 3, 2, 'Q383_R96_C4'),
#   (0.9100548028945923, 4, 2, 'Q383_R96_C5'),
#   (0.853111982345581, 7, 2, 'Q383_R96_C8'),
#   (0.6016384959220886, 1, 1, 'Q383_R96_C2'),
#   (0.33874690532684326, 6, 0, 'Q383_R96_C7'),
#   (0.33874690532684326, 5, 0, 'Q383_R96_C6'),
#   (0.25165170431137085, 8, 2, 'Q383_R96_C9'),
#   (0.18917956948280334, 9, 0, 'Q383_R96_C10'),
#   (0.1693597137928009, 0, 0, 'Q383_R96_C1'),
#   (0.09279890358448029, 2, 0, 'Q383_R96_C3')],
#  [(1.0085678100585938, 1, 2, 'Q384_R1_C2'),
#   (0.9966080188751221, 5, 2, 'Q384_R1_C6'),
#   (0.9301605224609375, 0, 2, 'Q384_R1_C1'),
#   (0.9051817655563354, 9, 2, 'Q384_R1_C10'),
#   (0.8984289169311523, 7, 1, 'Q384_R1_C8'),
#   (0.20150870084762573, 8, 1, 'Q384_R1_C9'),
#   (0.17176157236099243, 4, 2, 'Q384_R1_C5'),
#   (0.14597336947917938, 2, 0, 'Q384_R1_C3'),
#   (0.1355280727148056, 6, 0, 'Q384_R1_C7'),
#   (0.1103799045085907, 3, 0, 'Q384_R1_C4')],
#  [(0.9042574167251587, 4, 2, 'Q384_R46_C5'),
#   (0.7059440016746521, 8, 2, 'Q384_R46_C9'),
#   (0.5307390689849854, 9, 2, 'Q384_R46_C10'),
#   (0.4162063002586365, 7, 0, 'Q384_R46_C8'),
#   (0.3872690796852112, 3, 2, 'Q384_R46_C4'),
#   (0.31479018926620483, 2, 2, 'Q384_R46_C3'),
#   (0.3008877635002136, 5, 2, 'Q384_R46_C6'),
#   (0.2084183394908905, 0, 0, 'Q384_R46_C1'),
#   (0.20011477172374725, 6, 0, 'Q384_R46_C7'),
#   (0.15178418159484863, 1, 0, 'Q384_R46_C2')],
#  [(0.8619701862335205, 4, 1, 'Q385_R2_C5'),
#   (0.800574541091919, 6, 1, 'Q385_R2_C7'),
#   (0.8001022934913635, 1, 2, 'Q385_R2_C2'),
#   (0.7901216745376587, 3, 1, 'Q385_R2_C4'),
#   (0.7567944526672363, 0, 0, 'Q385_R2_C1'),
#   (0.7140066623687744, 9, 2, 'Q385_R2_C10'),
#   (0.7000359296798706, 7, 2, 'Q385_R2_C8'),
#   (0.30965301394462585, 8, 1, 'Q385_R2_C9'),
#   (0.18745028972625732, 5, 0, 'Q385_R2_C6'),
#   (0.1162102073431015, 2, 0, 'Q385_R2_C3')],
#  [(0.9382575750350952, 9, 2, 'Q385_R4_C10'),
#   (0.9345992803573608, 2, 2, 'Q385_R4_C3'),
#   (0.8960542678833008, 4, 1, 'Q385_R4_C5'),
#   (0.8214701414108276, 3, 2, 'Q385_R4_C4'),
#   (0.7569646835327148, 1, 1, 'Q385_R4_C2'),
#   (0.7325912714004517, 6, 0, 'Q385_R4_C7'),
#   (0.5865064859390259, 0, 0, 'Q385_R4_C1'),
#   (0.4854905307292938, 5, 0, 'Q385_R4_C6'),
#   (0.23038038611412048, 7, 0, 'Q385_R4_C8'),
#   (0.12230426073074341, 8, 2, 'Q385_R4_C9')],
#  [(0.9111175537109375, 8, 2, 'Q385_R10_C9'),
#   (0.8089505434036255, 1, 2, 'Q385_R10_C2'),
#   (0.7900453805923462, 2, 2, 'Q385_R10_C3'),
#   (0.7848548889160156, 9, 0, 'Q385_R10_C10'),
#   (0.7819293141365051, 0, 2, 'Q385_R10_C1'),
#   (0.6880804896354675, 5, 0, 'Q385_R10_C6'),
#   (0.4701237678527832, 7, 0, 'Q385_R10_C8'),
#   (0.26865559816360474, 3, 0, 'Q385_R10_C4'),
#   (0.2513478100299835, 4, 0, 'Q385_R10_C5'),
#   (0.07358506321907043, 6, 0, 'Q385_R10_C7')],
#  [(0.8946459293365479, 3, 2, 'Q385_R25_C4'),
#   (0.7447794079780579, 9, 0, 'Q385_R25_C10'),
#   (0.6026097536087036, 2, 0, 'Q385_R25_C3'),
#   (0.5631361603736877, 7, 1, 'Q385_R25_C8'),
#   (0.5610330104827881, 4, 2, 'Q385_R25_C5'),
#   (0.39079898595809937, 0, 1, 'Q385_R25_C1'),
#   (0.22732879221439362, 1, 2, 'Q385_R25_C2'),
#   (0.06313362717628479, 8, 0, 'Q385_R25_C9'),
#   (0.055604517459869385, 5, 0, 'Q385_R25_C6'),
#   (0.040893614292144775, 6, 0, 'Q385_R25_C7')],
#  [(0.9441955089569092, 3, 2, 'Q385_R30_C4'),
#   (0.836309552192688, 9, 0, 'Q385_R30_C10'),
#   (0.8352439403533936, 5, 2, 'Q385_R30_C6'),
#   (0.7718409299850464, 4, 0, 'Q385_R30_C5'),
#   (0.7317059636116028, 0, 2, 'Q385_R30_C1'),
#   (0.5787664651870728, 1, 2, 'Q385_R30_C2'),
#   (0.5509394407272339, 2, 2, 'Q385_R30_C3'),
#   (0.3464745879173279, 6, 0, 'Q385_R30_C7'),
#   (0.21265681087970734, 7, 2, 'Q385_R30_C8'),
#   (0.14834292232990265, 8, 0, 'Q385_R30_C9')],
#  [(0.8861590623855591, 0, 1, 'Q385_R31_C1'),
#   (0.8797621726989746, 4, 1, 'Q385_R31_C5'),
#   (0.8580460548400879, 9, 2, 'Q385_R31_C10'),
#   (0.827254056930542, 7, 2, 'Q385_R31_C8'),
#   (0.4157228469848633, 6, 1, 'Q385_R31_C7'),
#   (0.21158181130886078, 2, 0, 'Q385_R31_C3'),
#   (0.1927143782377243, 3, 0, 'Q385_R31_C4'),
#   (0.19040155410766602, 5, 0, 'Q385_R31_C6'),
#   (0.18186832964420319, 1, 1, 'Q385_R31_C2'),
#   (0.10382373631000519, 8, 0, 'Q385_R31_C9')],
#  [(0.897199273109436, 6, 2, 'Q385_R34_C7'),
#   (0.7510004043579102, 5, 2, 'Q385_R34_C6'),
#   (0.7493751049041748, 1, 2, 'Q385_R34_C2'),
#   (0.37300801277160645, 0, 2, 'Q385_R34_C1'),
#   (0.32544538378715515, 2, 2, 'Q385_R34_C3'),
#   (0.17873899638652802, 4, 0, 'Q385_R34_C5'),
#   (0.17035605013370514, 9, 2, 'Q385_R34_C10'),
#   (0.10410016775131226, 8, 0, 'Q385_R34_C9'),
#   (0.09414546191692352, 7, 0, 'Q385_R34_C8'),
#   (0.08524467051029205, 3, 0, 'Q385_R34_C4')],
#  [(0.9884313344955444, 4, 2, 'Q386_R1_C5'),
#   (0.9874595403671265, 9, 2, 'Q386_R1_C10'),
#   (0.9585475921630859, 1, 2, 'Q386_R1_C2'),
#   (0.9567562341690063, 8, 2, 'Q386_R1_C9'),
#   (0.9436976909637451, 5, 2, 'Q386_R1_C6'),
#   (0.9235879182815552, 0, 2, 'Q386_R1_C1'),
#   (0.8890048265457153, 3, 2, 'Q386_R1_C4'),
#   (0.88177490234375, 7, 2, 'Q386_R1_C8'),
#   (0.6676265001296997, 2, 2, 'Q386_R1_C3'),
#   (0.6100770831108093, 6, 2, 'Q386_R1_C7')],
#  [(1.1166833639144897, 3, 2, 'Q386_R4_C4'),
#   (1.0815945863723755, 8, 2, 'Q386_R4_C9'),
#   (1.0735173225402832, 1, 2, 'Q386_R4_C2'),
#   (1.0612213611602783, 2, 2, 'Q386_R4_C3'),
#   (1.0521231889724731, 0, 2, 'Q386_R4_C1'),
#   (1.0443934202194214, 4, 2, 'Q386_R4_C5'),
#   (1.0146384239196777, 7, 2, 'Q386_R4_C8'),
#   (1.004103183746338, 6, 2, 'Q386_R4_C7'),
#   (0.9555492401123047, 5, 2, 'Q386_R4_C6'),
#   (0.9394574165344238, 9, 2, 'Q386_R4_C10')],
#  [(0.9910492897033691, 1, 1, 'Q386_R10_C2'),
#   (0.8635413646697998, 8, 1, 'Q386_R10_C9'),
#   (0.8290320634841919, 2, 2, 'Q386_R10_C3'),
#   (0.827727198600769, 9, 1, 'Q386_R10_C10'),
#   (0.8192262053489685, 4, 1, 'Q386_R10_C5'),
#   (0.7579387426376343, 3, 0, 'Q386_R10_C4'),
#   (0.3450542092323303, 0, 1, 'Q386_R10_C1'),
#   (0.26012614369392395, 5, 0, 'Q386_R10_C6'),
#   (0.13924869894981384, 7, 0, 'Q386_R10_C8'),
#   (0.07993853092193604, 6, 0, 'Q386_R10_C7')],
#  [(1.0557315349578857, 0, 2, 'Q386_R19_C1'),
#   (0.9814637899398804, 3, 0, 'Q386_R19_C4'),
#   (0.8172669410705566, 7, 0, 'Q386_R19_C8'),
#   (0.7945055961608887, 9, 0, 'Q386_R19_C10'),
#   (0.5209429264068604, 4, 0, 'Q386_R19_C5'),
#   (0.35860371589660645, 5, 0, 'Q386_R19_C6'),
#   (0.31730353832244873, 2, 0, 'Q386_R19_C3'),
#   (0.17311736941337585, 6, 0, 'Q386_R19_C7'),
#   (0.15414445102214813, 8, 0, 'Q386_R19_C9'),
#   (0.15331363677978516, 1, 0, 'Q386_R19_C2')],
#  [(0.9405791759490967, 0, 1, 'Q386_R32_C1'),
#   (0.9384747743606567, 8, 2, 'Q386_R32_C9'),
#   (0.936976432800293, 7, 2, 'Q386_R32_C8'),
#   (0.9360345602035522, 5, 2, 'Q386_R32_C6'),
#   (0.9325259923934937, 1, 2, 'Q386_R32_C2'),
#   (0.9217867851257324, 9, 2, 'Q386_R32_C10'),
#   (0.8993299007415771, 2, 2, 'Q386_R32_C3'),
#   (0.8950949907302856, 3, 2, 'Q386_R32_C4'),
#   (0.8744909763336182, 4, 2, 'Q386_R32_C5'),
#   (0.16533906757831573, 6, 2, 'Q386_R32_C7')],
#  [(0.9436967372894287, 8, 1, 'Q386_R35_C9'),
#   (0.9003785848617554, 5, 2, 'Q386_R35_C6'),
#   (0.8683077096939087, 6, 2, 'Q386_R35_C7'),
#   (0.678007960319519, 4, 1, 'Q386_R35_C5'),
#   (0.2265397012233734, 2, 0, 'Q386_R35_C3'),
#   (0.224714994430542, 3, 0, 'Q386_R35_C4'),
#   (0.1481800377368927, 7, 0, 'Q386_R35_C8'),
#   (0.14310401678085327, 9, 0, 'Q386_R35_C10'),
#   (0.1378919929265976, 1, 2, 'Q386_R35_C2'),
#   (0.13768823444843292, 0, 2, 'Q386_R35_C1')],
#  [(0.7716511487960815, 7, 0, 'Q386_R47_C8'),
#   (0.6535327434539795, 8, 0, 'Q386_R47_C9'),
#   (0.6209995746612549, 2, 2, 'Q386_R47_C3'),
#   (0.49615901708602905, 6, 0, 'Q386_R47_C7'),
#   (0.24741508066654205, 1, 0, 'Q386_R47_C2'),
#   (0.232441246509552, 4, 0, 'Q386_R47_C5'),
#   (0.21731677651405334, 9, 1, 'Q386_R47_C10'),
#   (0.20701342821121216, 0, 0, 'Q386_R47_C1'),
#   (0.1978025883436203, 5, 2, 'Q386_R47_C6'),
#   (0.05586078763008118, 3, 0, 'Q386_R47_C4')],
#  [(0.9930546283721924, 7, 2, 'Q387_R7_C8'),
#   (0.9863450527191162, 1, 2, 'Q387_R7_C2'),
#   (0.9041799306869507, 0, 0, 'Q387_R7_C1'),
#   (0.8906540870666504, 8, 2, 'Q387_R7_C9'),
#   (0.8825163841247559, 2, 0, 'Q387_R7_C3'),
#   (0.8534473180770874, 4, 2, 'Q387_R7_C5'),
#   (0.7886325120925903, 6, 1, 'Q387_R7_C7'),
#   (0.5942736864089966, 3, 0, 'Q387_R7_C4'),
#   (0.2260044813156128, 5, 0, 'Q387_R7_C6'),
#   (0.08189007639884949, 9, 0, 'Q387_R7_C10')],
#  [(0.9669489860534668, 4, 0, 'Q387_R24_C5'),
#   (0.9666092395782471, 1, 2, 'Q387_R24_C2'),
#   (0.9158990383148193, 6, 1, 'Q387_R24_C7'),
#   (0.9092155694961548, 7, 1, 'Q387_R24_C8'),
#   (0.834815263748169, 5, 0, 'Q387_R24_C6'),
#   (0.6389917135238647, 0, 1, 'Q387_R24_C1'),
#   (0.5806432366371155, 2, 1, 'Q387_R24_C3'),
#   (0.580573320388794, 9, 0, 'Q387_R24_C10'),
#   (0.10713352262973785, 8, 0, 'Q387_R24_C9'),
#   (0.09419804811477661, 3, 0, 'Q387_R24_C4')],
#  [(0.949482798576355, 2, 2, 'Q387_R30_C3'),
#   (0.9426146745681763, 4, 2, 'Q387_R30_C5'),
#   (0.8442361354827881, 0, 2, 'Q387_R30_C1'),
#   (0.8120542764663696, 6, 2, 'Q387_R30_C7'),
#   (0.7950869798660278, 9, 1, 'Q387_R30_C10'),
#   (0.7805122137069702, 8, 2, 'Q387_R30_C9'),
#   (0.6379305124282837, 1, 0, 'Q387_R30_C2'),
#   (0.5750942230224609, 7, 0, 'Q387_R30_C8'),
#   (0.24962860345840454, 3, 2, 'Q387_R30_C4'),
#   (0.11985315382480621, 5, 0, 'Q387_R30_C6')],
#  [(1.0320452451705933, 0, 2, 'Q387_R41_C1'),
#   (0.9689645767211914, 5, 1, 'Q387_R41_C6'),
#   (0.9391088485717773, 2, 2, 'Q387_R41_C3'),
#   (0.9288209676742554, 7, 2, 'Q387_R41_C8'),
#   (0.9116445779800415, 4, 2, 'Q387_R41_C5'),
#   (0.8940428495407104, 8, 2, 'Q387_R41_C9'),
#   (0.7683471441268921, 1, 2, 'Q387_R41_C2'),
#   (0.35041454434394836, 3, 0, 'Q387_R41_C4'),
#   (0.19816142320632935, 6, 0, 'Q387_R41_C7'),
#   (0.11587272584438324, 9, 0, 'Q387_R41_C10')],
#  [(0.9743701219558716, 6, 0, 'Q387_R44_C7'),
#   (0.8556627035140991, 9, 0, 'Q387_R44_C10'),
#   (0.7493659257888794, 5, 0, 'Q387_R44_C6'),
#   (0.2343023717403412, 0, 1, 'Q387_R44_C1'),
#   (0.19212093949317932, 3, 2, 'Q387_R44_C4'),
#   (0.1773965060710907, 7, 0, 'Q387_R44_C8'),
#   (0.1725142002105713, 8, 2, 'Q387_R44_C9'),
#   (0.13145220279693604, 2, 0, 'Q387_R44_C3'),
#   (0.09951353073120117, 1, 0, 'Q387_R44_C2'),
#   (0.0037108957767486572, 4, 0, 'Q387_R44_C5')]]

# %%
mc = MeasurementCalculator(ranks, 2)
print(mc.meanAveragePrecision())
print(mc.averageRecall())
print(mc.meanReciprocalRank())
# Out:
# 0.7245327612583147
# 0.6520235668171448
# 0.8040410659676714

# %% [markdown]
# The result is shown above. The MAP is 72.45% and the MRR is 80.40%. We didn't show the averageRecall because it is not a standard matric to evaluate the ranking and doesn't have a unified definition. Thus its value isn't informative.
